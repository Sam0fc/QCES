# %% [markdown]
# <a href="https://colab.research.google.com/github/johnryantaylor/QCES/blob/main/Project2_transport.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project 2: Tracer transport
#
# A critical aspect of understanding climate and environmental systems is describing the movement of substances. This could include pollution or water vapor in the atmosphere, salt in an estuary, or chemicals in a river. We often model the transport of these substances using an advection/diffusion equation for the concentration of the substance. In this context, we sometimes refer to the concentration field as a `tracer' since it helps us track the movement of individual molecules. We can also use this framework to describe the transport of heat, although in this case the tracer field (temperature or heat content) tracks the movement of thermal energy.
#
# In this project we will use Dedalus to solve advection diffusion equations to describe the vertical distribution of heat in the ocean and the concentration of pollution in a river.
#
# Student tasks are in [Section 1.4](#section1pt4), [Section 1.6](#section1pt6), and [Section 2.3](#section2pt3)

# %% [markdown]
# ## Setup
# If you are using Google colab, run the script below to install Dedalus

# %%
# Set environment variables for best performance
# %env OMP_NUM_THREADS=1
# %env NUMEXPR_MAX_THREADS=1

# Minimize logging output
import logging
logging.disable(logging.DEBUG)

# Check if running on google colab
import os
using_google_colab = bool(os.getenv("COLAB_RELEASE_TAG"))

# Check for Dedalus
try:
    import dedalus.public as de
    print("Dedalus already installed :)")
except:
    print("Dedalus not installed yet.")
    if using_google_colab:
        print("Installing for Google Colab.")
        print()
        # Step 1: Install FFTW
        # !apt-get install libfftw3-dev
        # !apt-get install libfftw3-mpi-dev
        # Step 2: Set paths for Dedalus installation
        import os
        os.environ['MPI_INCLUDE_PATH'] = "/usr/lib/x86_64-linux-gnu/openmpi/include"
        os.environ['MPI_LIBRARY_PATH'] = "/usr/lib/x86_64-linux-gnu"
        os.environ['FFTW_INCLUDE_PATH'] = "/usr/include"
        os.environ['FFTW_LIBRARY_PATH'] = "/usr/lib/x86_64-linux-gnu"
        # Step 3: Install Dedalus using pip
        # !pip3 install cython "mpi4py<4.0" numpy setuptools wheel
        # !CC=mpicc pip3 install --no-cache --no-build-isolation http://github.com/dedalusproject/dedalus/zipball/master/
        # !pip3 install -q ipympl
        # Step 4: Check installation
        print()
        try:
            import dedalus.public as de
            print("Dedalus successfully installed :)")
        except:
            print("Error installing Dedalus :(")
            raise
    else:
        print("See website for installation instructions:")
        print("https://dedalus-project.readthedocs.io/en/latest/pages/installation.html")

# Setup interactive matplotlib
if using_google_colab:
    from google.colab import output
    output.enable_custom_widget_manager()
# Out:
# env: OMP_NUM_THREADS=1
# env: NUMEXPR_MAX_THREADS=1
# Dedalus already installed :)

# %% [markdown]
# ## 1. Thermal structure in the ocean
#
# Most of the ocean has a stable thermal stratification with warm water at the surface and cold water in the abyss (exceptions occur in salt-stratified waters like the Arctic Ocean). Since the ocean is a massive thermal reservoir, understanding the distribution of this heat is important to quantifying the ocean's role in a changing climate. The structure of the temperature field can also inform us about the circulation in the ocean interior.

# %% [markdown]
# ### 1.1 Measured temperature profile
#
# The code below plots a sample temperature profile obtained off the coast of California. The data was obtained by digitizing Figure 3 in Munk, 1966.

# %%
import matplotlib.pyplot as plt

# Temperature measurements extracted from Figure 3 in Munk, 1966
CTD_T = [1.1296296296296295, 1.122004357298475, 1.1143790849673203, 1.1067538126361656, 1.1143790849673203, 1.1143790849673203, 1.1372549019607843, 1.122004357298475, 1.1372549019607843, 1.1525054466230937, 1.2287581699346406, 1.2745098039215685, 1.343137254901961, 1.4041394335511983, 1.526143790849673, 1.6405228758169934, 1.8997821350762527, 2.242919389978214, 2.69281045751634, 3.104575163398693, 3.104575163398693, 3.218954248366013, 3.4324618736383443, 3.8289760348583877, 4.042483660130719, 4.438997821350762]
CTD_z = [-4976.958525345623, -4869.431643625192, -4677.419354838709, -4470.046082949309, -4270.353302611367, -4070.6605222734256, -3932.411674347158, -3786.4823348694317, -3586.78955453149, -3394.7772657450078, -3195.084485407066, -2995.3917050691243, -2803.379416282642, -2580.6451612903224, -2350.230414746544, -2112.1351766513058, -1843.3179723502303, -1597.5422427035332, -1344.0860215053763, -1144.3932411674346, -1144.3932411674346, -1121.351766513057, -990.7834101382491, -821.8125960061443, -698.9247311827958, -583.7173579109067]

plt.scatter(CTD_T,CTD_z,s=10)
plt.xlabel('T (ºC)')
plt.ylabel('Depth (m)')
# Out:
# Text(0, 0.5, 'Depth (m)')

# %% [markdown]
# ### 1.2 Abyssal recipes
#
# Munk (1966) proposed that the thermal structure of the ocean interior is set by a balance between upwelling and diffusion. In this view, cold waters sink near the poles and spread across the seafloor before slowly rising through the ocean interior. If we assume, as Munk did, that the water upwells uniformly across the globe, the upwelling speed is approximately $10^{-7}$ m/s. This is far too small to directly measure, but it is large enough to have a major impact on the distribution of tracers. Since light can only penetrate through the top ~100m of ocean, we can ignore solar heating, except in that it sets the temperature near the ocean surface.

# %% [markdown]
# ### 1.3 Steady advection/diffusion equation
#
# Dedalus can solve differential equations in various forms. In addition to time-dependent initial value problems (IVPs), Dedalus can solve linear and nonlinear boundary value problems. The code below uses Dedalus to solve a linear boundary value problem (IVBP) for the steady state advection/diffusion equation.
#
# Here, the top and bottom temperature are set from the measured profile and these are used as boundary conditions. The vertical (upwelling) velocity is set to $10^{-7} m/s$, and the diffusivity is set to $10^{-7}$ $m^2/s$, to approximate the molecular diffusivity of heat in seawater.

# %%
"""
Dedalus script to solve the steady advection/diffusion equation
"""

import numpy as np
import matplotlib.pyplot as plt
import dedalus.public as d3
import logging
logger = logging.getLogger(__name__)

# Set various parameters. Note that the depth and the top and bottom temperature 
# are taken from the CTD data in the code cell above. That cell must be run first to define CTD_T and CTD_z.
z_surface = CTD_z[-1]
z_bottom = CTD_z[0]
T_surface = CTD_T[-1]
T_bottom = CTD_T[0]
Nz = 1000

# Set the upwelling velocity
w = 1e-7 # m/s
# Set the diffusivity
kappa=8.5e-5 # m^2/s

# Bases
zcoord = d3.Coordinate('z')
dist = d3.Distributor(zcoord, dtype=np.float64)
zbasis = d3.Chebyshev(zcoord, size=Nz, bounds=(z_bottom, z_surface))
z = dist.local_grid(zbasis)

# Fields
T = dist.Field(name='T', bases=zbasis)

# Add two tau variables to allow us to apply two boundary conditions
tau_1 = dist.Field(name='tau_1')
tau_2 = dist.Field(name='tau_2')
lift_basis = zbasis.derivative_basis(1)
lift = lambda A: d3.Lift(A, lift_basis, -1)

# Substitutions
dz = lambda A: d3.Differentiate(A, zcoord)
Tz = dz(T) + lift(tau_1)
Tzz = dz(Tz) + lift(tau_2)

# Problem
problem = d3.LBVP([T, tau_1, tau_2], namespace=locals())
problem.add_equation("w*Tz - kappa*Tzz = 0")
problem.add_equation("T(z=z_surface) = T_surface")
problem.add_equation("T(z=z_bottom) = T_bottom")

# Solver
solver = problem.build_solver()
solver.solve()

# Plot
plt.figure(figsize=(6, 4))
Tg=T['g']
plt.scatter(CTD_T,CTD_z,s=10)
plt.plot(Tg,z,'k')
plt.xlabel('Temperature (ºC)')
plt.ylabel('Depth (m)')
# Out:
# 2024-12-20 08:05:44,616 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.5e+01/s
# Text(0, 0.5, 'Depth (m)')

# %% [markdown]
# ### 1.4 Student investigation
# <a id='section1pt4'></a>
# Note that the profile above is not a good fit to the data. This implies that molecular diffusion isn't sufficient to transport heat down from the surface and stop the ocean from filling up with cold, dense water.
#
# Munk (1966) proposed that small-scale turbulence in the ocean interior results in a diffusivity that is orders of magnitude larger than the molecular value. Find a diffusivity that gives a good match with the data and test it in the Dedalus script above. Comment on the ability of this model (steady advection/diffusion) to fit the data.

# %% [markdown]
# **Diffusivity of about $8.5\times 10^{-5}$ gives a relatively good fit, but it seems that we cannot perfectly model these data with the assumption of one diffusivity, instead, a lower diffusivity seems to match better at deep depths, and higher value of kappa at shallow depths. This may be because of the relationship between diffusivity and temperature, or due to a relationship between stratification/density differenes and turbulence which could provide a control.**
#
# ### 1.5 Turning ocean mixing upside down
#
# Decades of research to measure the turbulent diffusivity in the ocean consistently found values much smaller than the one predicted by Munk (1966). Specifically, while larger values of the turbulent diffusivity were found near the bottom of the ocean over rough topographic features, the values in the upper ocean were about 10x smaller than the values predicted by Munk. 50 years after Munk's seminal paper, Ferrari et al. (2016) proposed that a depth-dependent turbulent diffusivity could be balanced by <em>downwelling</em>, with negative vertical velocities in the ocean interior. In this theory, the overturning circulation is upwelling in thin boundary layers along the sloping sides of the ocean basins.
#
# When the diffusivity, $\kappa$, is a function of $z$, the steady advection/diffusion equation can be written
#
# $$ w\frac{dT}{dz} = \frac{d}{dz}\left(\kappa(z) \frac{dT}{dz}\right)$$
#
# The Dedalus script below solves the previous equation and again compares the results with the observed temperature profile. For the depth-dependent diffusivity, $\kappa(z)$, we take
#
# $$ \kappa(z)=\kappa_{bg} + (\kappa_0-\kappa_{bg})e^{-(z+D)/l} $$
#
# using the form from Rogers et al., 2023, where $\kappa_{bg}=1\times 10^{-5} m^2/s$ is the background diffusivity characteristic of the upper water column, $\kappa_0=8.6\times 10^{-4} m^2/s$ characterizes the enhanced mixing near the bottom of the ocean, $D$ is a reference depth where $\kappa=\kappa_0$, and $l=667m$ is an exponential decay scale. In the script below, we start with $w=0$.

# %%
"""
Dedalus script to solve the steady advection/diffusion equation
with a spatially-variable diffusivity
"""

import numpy as np
import matplotlib.pyplot as plt
import dedalus.public as d3
import logging
logger = logging.getLogger(__name__)

w_intervals = 12
w_start = 1e-10
w_end = 1e-5

k0_intervals = 5
k0_start = 1e-5
k0_end = 1e-3

k_bg_intervals = 5
k_bg_start = 1e-5
k_bg_end = 1e-3

fig, axs = plt.subplots(nrows=k0_intervals,ncols=k_bg_intervals, figsize=(40,40), sharex=True, sharey=True)
for row,k0 in enumerate(np.logspace(np.log10(k0_start),np.log10(k0_end),k0_intervals)):
    for col,k_bg in enumerate(np.logspace(np.log10(k_bg_start),np.log10(k_bg_end),k_bg_intervals)):
        axs[row,col].set_title('k0='+str(round(k0,5))+', k_bg='+str(round(k_bg,5)))
        plt.sca(axs[row,col])
        for index,w in enumerate(np.logspace(np.log10(w_start),np.log10(w_end),w_intervals)):
# Set various parameters. Note that the depth and the top and bottom temperature 
# are taken from the CTD data in the code cell above. That cell must be run first to define CTD_T and CTD_z.
            z_surface = CTD_z[-1]
            z_bottom = CTD_z[0]
            T_surface = CTD_T[-1]
            T_bottom = CTD_T[0]
            Nz = 1000

# Set the vertical velocity

# Bases
            zcoord = d3.Coordinate('z')
            dist = d3.Distributor(zcoord, dtype=np.float64)
            zbasis = d3.Chebyshev(zcoord, size=Nz, bounds=(z_bottom, z_surface))
            z = dist.local_grid(zbasis)

# Fields
            T = dist.Field(name='T', bases=zbasis)
            kappa = dist.Field(name='kappa', bases=zbasis)
# Set the diffusivity
# Below is the diffusivity profile from Rogers et al., 2023
            kappa['g']= k0 + (k_bg-k0)*np.exp((-5e3-z)/667) # m^2/s
            # kappa['g']=1e-5 + (8.6e-4-1e-5)*np.exp((-5e3-z)/667) # m^2/s

# Add two tau variables to allow us to apply two boundary conditions
            tau_1 = dist.Field(name='tau_1')
            tau_2 = dist.Field(name='tau_2')
            lift_basis = zbasis.derivative_basis(1)
            lift = lambda A: d3.Lift(A, lift_basis, -1)

# Substitutions
            dz = lambda A: d3.Differentiate(A, zcoord)
            Tz = dz(T) + lift(tau_1)
            Tzz = dz(Tz) + lift(tau_2)

# Problem
            problem = d3.LBVP([T, tau_1, tau_2], namespace=locals())
            problem.add_equation("w*Tz - dz(kappa*Tz) + lift(tau_2) = 0")
            problem.add_equation("T(z=z_surface) = T_surface")
            problem.add_equation("T(z=z_bottom) = T_bottom")

# Solver
            solver = problem.build_solver()
            solver.solve()

# Plot
            Tg=T['g']
            plt.plot(Tg,z,label='w='+str(w))
        plt.scatter(CTD_T,CTD_z,s=10)
        plt.xlabel('Temperature (ºC)')
        plt.ylabel('Depth (m)')
        plt.legend() 
plt.tight_layout()
plt.savefig('transport.png')
plt.show()
# Out:
# 2024-12-20 08:05:45,147 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.4e+01/s
# 2024-12-20 08:05:45,248 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.1e+01/s
# 2024-12-20 08:05:45,347 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s
# 2024-12-20 08:05:45,436 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:45,551 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.1e+01/s
# 2024-12-20 08:05:45,642 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:45,728 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.4e+01/s
# 2024-12-20 08:05:45,819 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:45,900 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.5e+01/s
# 2024-12-20 08:05:45,993 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:46,084 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:46,171 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:46,365 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:05:46,518 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.2e+00/s
# 2024-12-20 08:05:46,668 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.3e+00/s
# 2024-12-20 08:05:46,829 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+00/s
# 2024-12-20 08:05:47,100 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 3.9e+00/s
# 2024-12-20 08:05:47,259 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+00/s
# 2024-12-20 08:05:47,429 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:05:47,585 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+00/s
# 2024-12-20 08:05:47,745 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+00/s
# 2024-12-20 08:05:47,916 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.3e+00/s
# 2024-12-20 08:05:48,076 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+00/s
# 2024-12-20 08:05:48,244 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:05:48,441 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:05:48,621 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:05:48,810 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:05:48,994 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:05:49,176 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:05:49,358 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:05:49,562 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:05:49,742 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:05:49,927 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:05:50,104 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:05:50,281 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.1e+00/s
# 2024-12-20 08:05:50,469 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:05:50,696 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:05:50,904 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:05:51,116 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:05:51,315 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+00/s
# 2024-12-20 08:05:51,511 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+00/s
# 2024-12-20 08:05:51,751 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.5e+00/s
# 2024-12-20 08:05:51,953 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:05:52,173 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:05:52,359 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:05:52,616 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.1e+00/s
# 2024-12-20 08:05:52,822 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:05:53,032 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:05:53,246 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:05:53,453 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:05:53,653 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+00/s
# 2024-12-20 08:05:53,848 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:05:54,046 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+00/s
# 2024-12-20 08:05:54,252 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:05:54,464 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:05:54,806 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 3.1e+00/s
# 2024-12-20 08:05:55,011 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:05:55,229 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-12-20 08:05:55,540 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 3.4e+00/s
# 2024-12-20 08:05:55,755 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-12-20 08:05:55,925 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+00/s
# 2024-12-20 08:05:56,093 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:05:56,286 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:05:56,474 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:05:56,639 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:05:56,807 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:05:56,979 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.3e+00/s
# 2024-12-20 08:05:57,148 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:05:57,320 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.3e+00/s
# 2024-12-20 08:05:57,480 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+00/s
# 2024-12-20 08:05:57,667 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:05:57,836 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:05:57,939 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:58,030 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:58,121 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:58,215 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:58,313 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s
# 2024-12-20 08:05:58,399 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.4e+01/s
# 2024-12-20 08:05:58,482 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.4e+01/s
# 2024-12-20 08:05:58,587 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.1e+01/s
# 2024-12-20 08:05:58,678 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:58,770 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:58,861 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:58,952 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:05:59,143 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:05:59,316 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.3e+00/s
# 2024-12-20 08:05:59,485 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:05:59,648 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.7e+00/s
# 2024-12-20 08:05:59,816 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:06:00,010 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:00,171 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+00/s
# 2024-12-20 08:06:00,333 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+00/s
# 2024-12-20 08:06:00,499 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:06:00,670 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:00,837 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:06:01,038 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+00/s
# 2024-12-20 08:06:01,268 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:06:01,482 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:06:01,710 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.7e+00/s
# 2024-12-20 08:06:01,963 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.2e+00/s
# 2024-12-20 08:06:02,233 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.1e+00/s
# 2024-12-20 08:06:02,574 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 3.1e+00/s
# 2024-12-20 08:06:02,791 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-12-20 08:06:02,996 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:03,206 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:06:03,424 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-12-20 08:06:03,638 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:06:03,861 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.8e+00/s
# 2024-12-20 08:06:04,121 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.7e+00/s
# 2024-12-20 08:06:04,356 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.5e+00/s
# 2024-12-20 08:06:04,566 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:06:04,800 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.6e+00/s
# 2024-12-20 08:06:04,996 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:05,202 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:06:05,407 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:06:05,629 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:06:05,833 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:06,044 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:06:06,264 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-12-20 08:06:06,478 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:06:06,690 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:06,873 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:07,063 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:07,260 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:07,494 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.6e+00/s
# 2024-12-20 08:06:07,702 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+00/s
# 2024-12-20 08:06:07,884 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:06:08,074 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:08,255 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:06:08,441 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:08,637 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:08,828 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:09,015 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:09,190 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.3e+00/s
# 2024-12-20 08:06:09,357 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:06:09,522 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:06:09,693 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:09,863 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:10,030 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:06:10,192 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+00/s
# 2024-12-20 08:06:10,359 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:06:10,524 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:06:10,691 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:06:10,864 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.3e+00/s
# 2024-12-20 08:06:10,975 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s
# 2024-12-20 08:06:11,070 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:06:11,165 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s
# 2024-12-20 08:06:11,451 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 3.7e+00/s
# 2024-12-20 08:06:11,545 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:06:11,642 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s
# 2024-12-20 08:06:11,738 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s
# 2024-12-20 08:06:11,836 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s
# 2024-12-20 08:06:11,933 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s
# 2024-12-20 08:06:12,026 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:06:12,115 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:06:12,203 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:06:12,437 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-12-20 08:06:12,624 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:12,811 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:13,003 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:13,194 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:13,406 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:06:13,595 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:13,774 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.1e+00/s
# 2024-12-20 08:06:13,949 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:06:14,132 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:14,316 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:14,497 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:06:14,705 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:14,902 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:15,103 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:15,293 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:15,477 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:15,662 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:15,843 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:16,029 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:16,211 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:16,395 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:16,577 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:16,759 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:16,956 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:17,141 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:17,353 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:06:17,570 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-12-20 08:06:17,774 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:17,966 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:18,148 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:18,340 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:18,526 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:18,709 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:19,028 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 3.3e+00/s
# 2024-12-20 08:06:19,214 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:19,415 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:19,607 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:19,800 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:19,994 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:20,200 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:06:20,405 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:20,635 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.6e+00/s
# 2024-12-20 08:06:20,831 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:21,033 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:21,228 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:21,414 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:21,597 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:21,777 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:06:21,945 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:22,113 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:22,280 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:22,449 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:22,615 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:06:22,783 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.5e+00/s
# 2024-12-20 08:06:22,951 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:23,133 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:06:23,314 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:06:23,483 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:23,657 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:06:23,757 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.4e+01/s
# 2024-12-20 08:06:23,839 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.5e+01/s
# 2024-12-20 08:06:23,924 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.4e+01/s
# 2024-12-20 08:06:24,015 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:06:24,104 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:06:24,191 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.4e+01/s
# 2024-12-20 08:06:24,285 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.2e+01/s
# 2024-12-20 08:06:24,378 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.4e+01/s
# 2024-12-20 08:06:24,469 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:06:24,557 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.3e+01/s
# 2024-12-20 08:06:24,632 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:24,711 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.5e+01/s
# 2024-12-20 08:06:24,895 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:06:25,064 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:25,237 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:06:25,412 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:06:25,584 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:06:25,761 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:06:25,943 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:26,126 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:26,319 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:26,503 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:26,724 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.8e+00/s
# 2024-12-20 08:06:26,949 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.8e+00/s
# 2024-12-20 08:06:27,177 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:06:27,390 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:06:27,585 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:27,922 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 3.1e+00/s
# 2024-12-20 08:06:28,135 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:06:28,351 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:06:28,564 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:06:28,754 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:28,955 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:29,133 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:06:29,363 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.7e+00/s
# 2024-12-20 08:06:29,544 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:06:29,771 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.1e+00/s
# 2024-12-20 08:06:29,955 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:30,168 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.0e+00/s
# 2024-12-20 08:06:30,372 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:06:30,571 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+00/s
# 2024-12-20 08:06:30,759 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:30,955 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:31,138 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:31,360 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.8e+00/s
# 2024-12-20 08:06:31,558 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+00/s
# 2024-12-20 08:06:31,743 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:31,929 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:32,139 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:32,340 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:32,528 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:32,745 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-12-20 08:06:32,927 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.0e+00/s
# 2024-12-20 08:06:33,120 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:33,326 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:06:33,530 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:33,720 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:33,901 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.9e+00/s
# 2024-12-20 08:06:34,092 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.6e+00/s
# 2024-12-20 08:06:34,296 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:34,513 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.2e+00/s
# 2024-12-20 08:06:34,733 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 4.9e+00/s
# 2024-12-20 08:06:34,921 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:35,108 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.7e+00/s
# 2024-12-20 08:06:35,313 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:35,487 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:06:35,690 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.3e+00/s
# 2024-12-20 08:06:35,876 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.8e+00/s
# 2024-12-20 08:06:36,074 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.4e+00/s
# 2024-12-20 08:06:36,248 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.1e+00/s
# 2024-12-20 08:06:36,444 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 5.5e+00/s
# 2024-12-20 08:06:36,614 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.3e+00/s
# 2024-12-20 08:06:36,702 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.5e+01/s
# 2024-12-20 08:06:36,777 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:36,851 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:36,924 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:36,998 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:37,071 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:37,144 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:37,219 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:37,293 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:37,368 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:37,442 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s
# 2024-12-20 08:06:37,516 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 1.6e+01/s

# %% [markdown]
# ### 1.6 Student investigation
# <a id='section1pt6'></a>
# Note from the results of the script above that the density profile is reasonable, even though $w=0$. In the box below, comment on the balance in this case and what this implies about the diffusive heat flux.
#
# Next, find a vertical velocity that produces a better agreement with the observations and report it below. Then, try varying the details of the $\kappa(z)$ profile. How sensitive is the optimal $w$ to your choice of $\kappa(z)$? What does this imply about the circulation in the ocean interior if $\kappa(z)$ varies between regions of smooth and rough topography?
#
# (As an aside, note that the requied vertical velocity is much smaller than the one used by Munk (1966). This implies that the dense, cold water that sinks at the poles must rise elsewhere. Ferrari et al. (2016) proposed that this occurs in boundary layers near the seafloor.)

# %% [markdown]
# **$w=10^{-8}$ is a better fit with the observations. The optimal value of $w$ is more sensitive to the choice of $\kappa_0$ than to $\kappa_{bg}$, though their is some sensitivity to both. $\kappa_0$ is the bottom diffusivity, so it implies that if $\kappa$ varies between topography, it means we set up a gradient in upwelling velocity to drive some ciruclation. Intuitively, it makes sense that a rough surface would induce more diffusion, so a higher bottom diffusivity which increases velocity and drives more turbulence and mixing in the rough areas.**
#
# ## 2. Transport of pollution in a river
#
# Advection/diffusion equations are a common way to model the material transport in many physical systems. In this section we will model the transport and dilution of a pollutants added to a river.
#
# For simplicity, we will model the river as a rectangular channel, and we will neglect depth variations. Let $x$ be the coordinate along the length of the river, and $y$ be the cross-stream coordinate. We will model the river current as
#
# $$ u(y) = U_0\left(1-\frac{(y-w/2)^2}{(w/2)^2}\right) $$
#
# where $w$ is the width of the river and $U_0$ is the maximum current speed which occurs at the center of the river (the $y$-coordinate will run from 0 to $w$).
#
# Since we want to know how the pollution levels vary in time, we will solve the time-dependent advection/diffusion equation. We will model the addition of pollution by adding a spatially-dependent source term to the right hand side of the equation governing pollutant concentration:
#
# $$ \frac{\partial c}{\partial t} + u(y)\frac{\partial c}{\partial x} = \kappa \nabla^2 c + S(x,y) $$
#
# where $\nabla^2=(\partial_x^2 + \partial_y^2)$ is the Laplacian operator for diffusion in 2D Cartesian coordinates, and $S$ is the source term.

# %% [markdown]
# ### 2.1 Dedalus script
#
# The script below solves the time-dependent advection/diffusion equation with a source term.

# %%
"""
Script to solve the time-dependent advection/diffusion equation
"""

import numpy as np
import matplotlib.pyplot as plt
import dedalus.public as dedalus
import logging
logger = logging.getLogger(__name__)

# Set parameters
U0 = 0.1 # maximum current speed in m/s
w = 10 # width of the river in m
L = 50 # length of the river section to simulate
kappa = 1e-2 # diffusivity in m^2/s
S0 = 1 # amplitude of the pollution source term
S_w = 1 # width of the source term in m
S_x = 10 # center of the forcing in x
S_y = 0 # center of the forcing in y
S_t = 1 # forcing timescale

# Numerical parameters
Nx = 256 # number of gridoints in x
Ny = 32 # number of gridpoints in y
stop_sim_time=1500 # end time in seconds
timestep = (L/Nx)/U0 # timestep in seconds, calculated from the CFL number

import numpy as np
import dedalus.public as dedalus
import logging
logger = logging.getLogger(__name__)

# Bases and coordinates
coords = dedalus.CartesianCoordinates('x', 'y')
dist = dedalus.Distributor(coords, dtype=np.float64)
xbasis = dedalus.RealFourier(coords['x'], size=Nx, bounds=(0, L), dealias=3/2)
ybasis = dedalus.ChebyshevT(coords['y'], size=Ny, bounds=(0, w), dealias=3/2)
x, y = dist.local_grids(xbasis, ybasis)
ex, ey = coords.unit_vector_fields(dist) # x and y unit vectors

# Fields
c = dist.Field(name='b', bases=(xbasis,ybasis))
u = dist.Field(name='u', bases=(xbasis,ybasis))
tau_1 = dist.Field(name='tau_1', bases=xbasis)
tau_2 = dist.Field(name='tau_2', bases=xbasis)

# Specify the velocity field
u['g'] = U0 * (1- (y - w/2)**2.0/(w/2)**2.0) # parabolic velocity profile

# Substitutions
lift_basis = ybasis.derivative_basis(1)
lift = lambda A: dedalus.Lift(A, lift_basis, -1)
grad_c = dedalus.grad(c) + ey*lift(tau_1)
dx = lambda A: dedalus.Differentiate(A, coords['x'])

S = dist.Field(name='u', bases=(xbasis,ybasis))
S['g'] = S0*np.exp(-(x-S_x)**2.0/S_w**2.0-(y-S_y)**2.0/S_w**2.0)

# Problem
problem = dedalus.IVP([c, tau_1, tau_2], namespace=locals())
problem.add_equation("dt(c) + u*dx(c) - kappa*div(grad_c) + lift(tau_2) = S/S_t")
problem.add_equation("c(y=0) = 0")
problem.add_equation("c(y=w) = 0")

# Now, set the solver
solver = problem.build_solver(dedalus.RK222)
solver.stop_sim_time = stop_sim_time

# Create an array to periodically save the concentration field for plotting later
c.change_scales(1)
c_save = [np.copy(c['g'])]; 

t_save = [solver.sim_time]; # Save the initial condition and the initial time
# Main loop
try:
    logger.info('Starting main loop')
    while solver.proceed:
        solver.step(timestep)
        if (solver.iteration-1) % 10 == 0:
            logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
            c.change_scales(1)
            c_save.append(np.copy(c['g']))
            t_save.append(solver.sim_time)
except:
    logger.error('Exception raised, triggering end of main loop.')
    raise
finally:
    solver.log_stats()

# Convert the variables to numpy arrays for allow array slicing
c_save = np.array(c_save)
# Out:
# 2024-12-20 08:06:48,231 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:06:48,234 __main__ 0/1 INFO :: Starting main loop
# 2024-12-20 08:06:48,849 __main__ 0/1 INFO :: Iteration=1, Time=1.953125e+00, dt=1.953125e+00
# 2024-12-20 08:06:48,877 __main__ 0/1 INFO :: Iteration=11, Time=2.148438e+01, dt=1.953125e+00
# 2024-12-20 08:06:48,903 __main__ 0/1 INFO :: Iteration=21, Time=4.101562e+01, dt=1.953125e+00
# 2024-12-20 08:06:48,930 __main__ 0/1 INFO :: Iteration=31, Time=6.054688e+01, dt=1.953125e+00
# 2024-12-20 08:06:48,969 __main__ 0/1 INFO :: Iteration=41, Time=8.007812e+01, dt=1.953125e+00
# 2024-12-20 08:06:48,998 __main__ 0/1 INFO :: Iteration=51, Time=9.960938e+01, dt=1.953125e+00
# 2024-12-20 08:06:49,022 __main__ 0/1 INFO :: Iteration=61, Time=1.191406e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,052 __main__ 0/1 INFO :: Iteration=71, Time=1.386719e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,074 __main__ 0/1 INFO :: Iteration=81, Time=1.582031e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,094 __main__ 0/1 INFO :: Iteration=91, Time=1.777344e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,114 __main__ 0/1 INFO :: Iteration=101, Time=1.972656e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,137 __main__ 0/1 INFO :: Iteration=111, Time=2.167969e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,158 __main__ 0/1 INFO :: Iteration=121, Time=2.363281e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,179 __main__ 0/1 INFO :: Iteration=131, Time=2.558594e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,199 __main__ 0/1 INFO :: Iteration=141, Time=2.753906e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,221 __main__ 0/1 INFO :: Iteration=151, Time=2.949219e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,244 __main__ 0/1 INFO :: Iteration=161, Time=3.144531e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,264 __main__ 0/1 INFO :: Iteration=171, Time=3.339844e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,283 __main__ 0/1 INFO :: Iteration=181, Time=3.535156e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,308 __main__ 0/1 INFO :: Iteration=191, Time=3.730469e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,329 __main__ 0/1 INFO :: Iteration=201, Time=3.925781e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,350 __main__ 0/1 INFO :: Iteration=211, Time=4.121094e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,372 __main__ 0/1 INFO :: Iteration=221, Time=4.316406e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,391 __main__ 0/1 INFO :: Iteration=231, Time=4.511719e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,411 __main__ 0/1 INFO :: Iteration=241, Time=4.707031e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,431 __main__ 0/1 INFO :: Iteration=251, Time=4.902344e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,453 __main__ 0/1 INFO :: Iteration=261, Time=5.097656e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,476 __main__ 0/1 INFO :: Iteration=271, Time=5.292969e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,497 __main__ 0/1 INFO :: Iteration=281, Time=5.488281e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,518 __main__ 0/1 INFO :: Iteration=291, Time=5.683594e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,539 __main__ 0/1 INFO :: Iteration=301, Time=5.878906e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,558 __main__ 0/1 INFO :: Iteration=311, Time=6.074219e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,578 __main__ 0/1 INFO :: Iteration=321, Time=6.269531e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,596 __main__ 0/1 INFO :: Iteration=331, Time=6.464844e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,614 __main__ 0/1 INFO :: Iteration=341, Time=6.660156e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,632 __main__ 0/1 INFO :: Iteration=351, Time=6.855469e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,657 __main__ 0/1 INFO :: Iteration=361, Time=7.050781e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,679 __main__ 0/1 INFO :: Iteration=371, Time=7.246094e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,700 __main__ 0/1 INFO :: Iteration=381, Time=7.441406e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,726 __main__ 0/1 INFO :: Iteration=391, Time=7.636719e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,753 __main__ 0/1 INFO :: Iteration=401, Time=7.832031e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,778 __main__ 0/1 INFO :: Iteration=411, Time=8.027344e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,801 __main__ 0/1 INFO :: Iteration=421, Time=8.222656e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,824 __main__ 0/1 INFO :: Iteration=431, Time=8.417969e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,846 __main__ 0/1 INFO :: Iteration=441, Time=8.613281e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,865 __main__ 0/1 INFO :: Iteration=451, Time=8.808594e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,887 __main__ 0/1 INFO :: Iteration=461, Time=9.003906e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,907 __main__ 0/1 INFO :: Iteration=471, Time=9.199219e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,927 __main__ 0/1 INFO :: Iteration=481, Time=9.394531e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,947 __main__ 0/1 INFO :: Iteration=491, Time=9.589844e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,967 __main__ 0/1 INFO :: Iteration=501, Time=9.785156e+02, dt=1.953125e+00
# 2024-12-20 08:06:49,992 __main__ 0/1 INFO :: Iteration=511, Time=9.980469e+02, dt=1.953125e+00
# 2024-12-20 08:06:50,015 __main__ 0/1 INFO :: Iteration=521, Time=1.017578e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,039 __main__ 0/1 INFO :: Iteration=531, Time=1.037109e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,062 __main__ 0/1 INFO :: Iteration=541, Time=1.056641e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,084 __main__ 0/1 INFO :: Iteration=551, Time=1.076172e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,107 __main__ 0/1 INFO :: Iteration=561, Time=1.095703e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,127 __main__ 0/1 INFO :: Iteration=571, Time=1.115234e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,146 __main__ 0/1 INFO :: Iteration=581, Time=1.134766e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,165 __main__ 0/1 INFO :: Iteration=591, Time=1.154297e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,185 __main__ 0/1 INFO :: Iteration=601, Time=1.173828e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,205 __main__ 0/1 INFO :: Iteration=611, Time=1.193359e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,224 __main__ 0/1 INFO :: Iteration=621, Time=1.212891e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,246 __main__ 0/1 INFO :: Iteration=631, Time=1.232422e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,265 __main__ 0/1 INFO :: Iteration=641, Time=1.251953e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,286 __main__ 0/1 INFO :: Iteration=651, Time=1.271484e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,308 __main__ 0/1 INFO :: Iteration=661, Time=1.291016e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,329 __main__ 0/1 INFO :: Iteration=671, Time=1.310547e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,349 __main__ 0/1 INFO :: Iteration=681, Time=1.330078e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,369 __main__ 0/1 INFO :: Iteration=691, Time=1.349609e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,391 __main__ 0/1 INFO :: Iteration=701, Time=1.369141e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,410 __main__ 0/1 INFO :: Iteration=711, Time=1.388672e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,431 __main__ 0/1 INFO :: Iteration=721, Time=1.408203e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,450 __main__ 0/1 INFO :: Iteration=731, Time=1.427734e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,471 __main__ 0/1 INFO :: Iteration=741, Time=1.447266e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,491 __main__ 0/1 INFO :: Iteration=751, Time=1.466797e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,511 __main__ 0/1 INFO :: Iteration=761, Time=1.486328e+03, dt=1.953125e+00
# 2024-12-20 08:06:50,527 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-12-20 08:06:50,527 solvers 0/1 INFO :: Final iteration: 768
# 2024-12-20 08:06:50,528 solvers 0/1 INFO :: Final sim time: 1500.0
# 2024-12-20 08:06:50,528 solvers 0/1 INFO :: Setup time (init - iter 0): 0.865 sec
# 2024-12-20 08:06:50,528 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.04637 sec
# 2024-12-20 08:06:50,529 solvers 0/1 INFO :: Run time (iter 10-end): 1.654 sec
# 2024-12-20 08:06:50,529 solvers 0/1 INFO :: CPU time (iter 10-end): 0.0004594 cpu-hr
# 2024-12-20 08:06:50,529 solvers 0/1 INFO :: Speed: 7.948e+06 mode-stages/cpu-sec

# %% [markdown]
# ## 2.2 Visualization
#
# The script below makes a movie of the results from the saved variables. To run this, you need to have ffmpeg installed.  If you don't already have it installed, you can install ffmpeg with the command:
#
# `conda install -c conda-forge ffmpeg`

# %%
# create a figure and axes
fig = plt.figure(figsize=(6,6))

# Create arrays with the latitude and longitude coordinates for plotting using pcolor
from dedalus.extras import plot_tools
(X, Y) = plot_tools.quad_mesh(np.squeeze(x), np.squeeze(y))  

# Define an animation function
def drawframe(n):
    plt.clf()
    concentration = plt.pcolor(X, Y, c_save[n,:,:].T)
    # Specify the axis limits and labels
    plt.axis('square')
    plt.xlim(0, L)   
    plt.ylim(0, w)  
    plt.xlabel('x (m)')
    plt.ylabel('y (m)')
    plt.title('concentration, time = {0:.2f} seconds'.format(t_save[n]))
    return (concentration,)

from matplotlib import animation
# blit=True re-draws only the parts that have changed.
anim = animation.FuncAnimation(fig, drawframe, frames=len(t_save), interval=40, blit=True)

from IPython.display import HTML
HTML(anim.to_html5_video())
# Out:
# 2024-12-20 08:06:50,615 matplotlib.animation 0/1 INFO :: Animation.save using <class 'matplotlib.animation.FFMpegWriter'>
# 2024-12-20 08:06:50,616 matplotlib.animation 0/1 INFO :: MovieWriter._run: running command: ffmpeg -f rawvideo -vcodec rawvideo -s 600x600 -pix_fmt rgba -framerate 25.0 -i pipe: -vcodec h264 -pix_fmt yuv420p -y /tmp/tmph2ft7wc5/temp.m4v
# <video width="600" height="600" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# ## 2.3 Student investigation
# <a id='section2pt3'></a>
# In the boxes below, plot the pollution concentration at a few points as a function of time. Then vary the maximum flow speed and the diffusivity and explore how the pollution levels depend on these parameters. Using dimensional analysis, estimate the time needed for the pollution to reach the opposite side of the river. How far downstream of the source do you expect this to happen (assuming that the domain in the x-direction is infinite).
#
# **From the multi-plot below, we can see that as kappa is increased, the actual concentration at most points decreases as the concentration is more evenly spread. Additionally, as the flow increases, the time until the concentration is seen at any point is decreased, as is the time till it reaches a steady state at that point.**
#
# **From the reference frame of the tracer moving along the river, we can assume advection is 0. The terms then scale as below:**
# $$ \frac{1}{t} \sim \frac{\kappa}{w^2} $$
# **Therefore, the time to reach the other side of the river is $t \sim w^2/\kappa$. The distance downstream is then $x \sim U_0 t \sim U_0 w^2/\kappa$. Subsituting our values gives a characteristic downstream distance of $1000\mathrm{m}$, which is probably an upperbound as $u \leq U_0$ across the river.**

# %%
import matplotlib.cm as cm
x_points = np.linspace(50,200,5,dtype=int)
y_points = np.linspace(5,20,5,dtype=int)
c_points = np.zeros((len(x_points), len(t_save)))
for i in range(len(x_points)):
    c_points[i,:] = c_save[:,x_points[i],y_points[i]]

fig = plt.figure(figsize=(6,4))
plt.xlabel('Time (s)')
plt.ylabel('Concentration')
# Inset plot with imshow of c_save
inset_ax = fig.get_axes()[0].inset_axes([0.65, 0.65, 0.3, 0.3])
inset_ax.imshow(c_save[-1, :, :].T, aspect='auto', origin='lower', extent=[0, L, 0, w])
for i,fmt in zip(range(len(x_points)),['red','blue','green','orange','black']):
    inset_ax.plot(L * x_points[i]/Nx, w * y_points[i]/Ny,  color=fmt,marker='x')
    plt.plot(t_save,c_points[i,:],label='x='+str(x_points[i]),color=fmt)
inset_ax.set_xticks([])
inset_ax.set_yticks([])
plt.title('Pollution concentration at different points,')
# Out:
# Text(0.5, 1.0, 'Pollution concentration at different points,')

# %%
# Varying flow speed and diffusivity
flow_speeds = [0.05, 0.1, 0.2]
diffusivities = [1e-4,1e-3, 1e-2]

fig, axs = plt.subplots(len(flow_speeds), len(diffusivities), figsize=(15, 10), sharex=True, sharey=True)
for row, flow_speed in enumerate(flow_speeds):
    for col, diffusivity in enumerate(diffusivities):
        """
        Script to solve the time-dependent advection/diffusion equation
        """

  

        # Set parameters
        U0 = flow_speed # maximum current speed in m/s
        w = 10 # width of the river in m
        L = 50 # length of the river section to simulate
        kappa = diffusivity # diffusivity in m^2/s
        S0 = 1 # amplitude of the pollution source term
        S_w = 1 # width of the source term in m
        S_x = 10 # center of the forcing in x
        S_y = 0 # center of the forcing in y
        S_t = 1 # forcing timescale

        # Numerical parameters
        Nx = 256 # number of gridoints in x
        Ny = 32 # number of gridpoints in y
        stop_sim_time=1500 # end time in seconds
        timestep = (L/Nx)/U0 # timestep in seconds, calculated from the CFL number

     
        logger = logging.getLogger(__name__)

        # Bases and coordinates
        coords = dedalus.CartesianCoordinates('x', 'y')
        dist = dedalus.Distributor(coords, dtype=np.float64)
        xbasis = dedalus.RealFourier(coords['x'], size=Nx, bounds=(0, L), dealias=3/2)
        ybasis = dedalus.ChebyshevT(coords['y'], size=Ny, bounds=(0, w), dealias=3/2)
        x, y = dist.local_grids(xbasis, ybasis)
        ex, ey = coords.unit_vector_fields(dist) # x and y unit vectors

        # Fields
        c = dist.Field(name='b', bases=(xbasis,ybasis))
        u = dist.Field(name='u', bases=(xbasis,ybasis))
        tau_1 = dist.Field(name='tau_1', bases=xbasis)
        tau_2 = dist.Field(name='tau_2', bases=xbasis)

        # Specify the velocity field
        u['g'] = U0 * (1- (y - w/2)**2.0/(w/2)**2.0) # parabolic velocity profile

        # Substitutions
        lift_basis = ybasis.derivative_basis(1)
        lift = lambda A: dedalus.Lift(A, lift_basis, -1)
        grad_c = dedalus.grad(c) + ey*lift(tau_1)
        dx = lambda A: dedalus.Differentiate(A, coords['x'])

        S = dist.Field(name='u', bases=(xbasis,ybasis))
        S['g'] = S0*np.exp(-(x-S_x)**2.0/S_w**2.0-(y-S_y)**2.0/S_w**2.0)

        # Problem
        problem = dedalus.IVP([c, tau_1, tau_2], namespace=locals())
        problem.add_equation("dt(c) + u*dx(c) - kappa*div(grad_c) + lift(tau_2) = S/S_t")
        problem.add_equation("c(y=0) = 0")
        problem.add_equation("c(y=w) = 0")

        # Now, set the solver
        solver = problem.build_solver(dedalus.RK222)
        solver.stop_sim_time = stop_sim_time

        # Create an array to periodically save the concentration field for plotting later
        c.change_scales(1)
        c_save = [np.copy(c['g'])]; 

        t_save = [solver.sim_time]; # Save the initial condition and the initial time
        # Main loop
        try:
            logger.info('Starting main loop')
            while solver.proceed:
                solver.step(timestep)
                if (solver.iteration-1) % 10 == 0:
                    logger.info('Iteration=%i, Time=%e, dt=%e' %(solver.iteration, solver.sim_time, timestep))
                    c.change_scales(1)
                    c_save.append(np.copy(c['g']))
                    t_save.append(solver.sim_time)
        except:
            logger.error('Exception raised, triggering end of main loop.')
            raise
        finally:
            solver.log_stats()
        
        c_save = np.array(c_save)
        c_points = np.zeros((len(x_points), len(t_save)))
        for i in range(len(x_points)):
            c_points[i,:] = c_save[:,x_points[i],5]
        axs[row,col].set_title('U0='+str(flow_speed)+', kappa='+str(diffusivity))
        axs[row,col].set_xlabel('Time (s)')
        axs[row,col].set_ylabel('Concentration')
        axs[row,col].legend()
        # Inset plot with imshow of c_save
        inset_ax = axs[row,col].inset_axes([0.65, 0.65, 0.3, 0.3])
        inset_ax.imshow(c_save[-1, :, :].T, aspect='auto', origin='lower', extent=[0, L, 0, w])
        for i,fmt in zip(range(len(x_points)),['red','blue','green','orange','black']):
            inset_ax.plot(L * x_points[i]/Nx, w * y_points[i]/Ny,  color=fmt,marker='x')
            axs[row,col].plot(t_save,c_points[i,:],label='x='+str(x_points[i]),color=fmt)
        inset_ax.set_xticks([])
        inset_ax.set_yticks([])
        

# Convert the variables to numpy arrays for allow array slicing
plt.tight_layout()
plt.show()
# Out:
# 2024-12-20 08:07:00,348 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.2e+00/s
# 2024-12-20 08:07:00,350 __main__ 0/1 INFO :: Starting main loop
# 2024-12-20 08:07:00,391 __main__ 0/1 INFO :: Iteration=1, Time=3.906250e+00, dt=3.906250e+00
# 2024-12-20 08:07:00,424 __main__ 0/1 INFO :: Iteration=11, Time=4.296875e+01, dt=3.906250e+00
# 2024-12-20 08:07:00,461 __main__ 0/1 INFO :: Iteration=21, Time=8.203125e+01, dt=3.906250e+00
# 2024-12-20 08:07:00,493 __main__ 0/1 INFO :: Iteration=31, Time=1.210938e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,520 __main__ 0/1 INFO :: Iteration=41, Time=1.601562e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,549 __main__ 0/1 INFO :: Iteration=51, Time=1.992188e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,571 __main__ 0/1 INFO :: Iteration=61, Time=2.382812e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,588 __main__ 0/1 INFO :: Iteration=71, Time=2.773438e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,603 __main__ 0/1 INFO :: Iteration=81, Time=3.164062e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,620 __main__ 0/1 INFO :: Iteration=91, Time=3.554688e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,641 __main__ 0/1 INFO :: Iteration=101, Time=3.945312e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,667 __main__ 0/1 INFO :: Iteration=111, Time=4.335938e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,689 __main__ 0/1 INFO :: Iteration=121, Time=4.726562e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,711 __main__ 0/1 INFO :: Iteration=131, Time=5.117188e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,735 __main__ 0/1 INFO :: Iteration=141, Time=5.507812e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,756 __main__ 0/1 INFO :: Iteration=151, Time=5.898438e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,784 __main__ 0/1 INFO :: Iteration=161, Time=6.289062e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,811 __main__ 0/1 INFO :: Iteration=171, Time=6.679688e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,842 __main__ 0/1 INFO :: Iteration=181, Time=7.070312e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,873 __main__ 0/1 INFO :: Iteration=191, Time=7.460938e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,905 __main__ 0/1 INFO :: Iteration=201, Time=7.851562e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,942 __main__ 0/1 INFO :: Iteration=211, Time=8.242188e+02, dt=3.906250e+00
# 2024-12-20 08:07:00,988 __main__ 0/1 INFO :: Iteration=221, Time=8.632812e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,022 __main__ 0/1 INFO :: Iteration=231, Time=9.023438e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,046 __main__ 0/1 INFO :: Iteration=241, Time=9.414062e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,070 __main__ 0/1 INFO :: Iteration=251, Time=9.804688e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,091 __main__ 0/1 INFO :: Iteration=261, Time=1.019531e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,117 __main__ 0/1 INFO :: Iteration=271, Time=1.058594e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,139 __main__ 0/1 INFO :: Iteration=281, Time=1.097656e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,163 __main__ 0/1 INFO :: Iteration=291, Time=1.136719e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,188 __main__ 0/1 INFO :: Iteration=301, Time=1.175781e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,208 __main__ 0/1 INFO :: Iteration=311, Time=1.214844e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,233 __main__ 0/1 INFO :: Iteration=321, Time=1.253906e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,254 __main__ 0/1 INFO :: Iteration=331, Time=1.292969e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,278 __main__ 0/1 INFO :: Iteration=341, Time=1.332031e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,301 __main__ 0/1 INFO :: Iteration=351, Time=1.371094e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,323 __main__ 0/1 INFO :: Iteration=361, Time=1.410156e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,345 __main__ 0/1 INFO :: Iteration=371, Time=1.449219e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,368 __main__ 0/1 INFO :: Iteration=381, Time=1.488281e+03, dt=3.906250e+00
# 2024-12-20 08:07:01,375 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-12-20 08:07:01,375 solvers 0/1 INFO :: Final iteration: 384
# 2024-12-20 08:07:01,376 solvers 0/1 INFO :: Final sim time: 1500.0
# 2024-12-20 08:07:01,376 solvers 0/1 INFO :: Setup time (init - iter 0): 0.1857 sec
# 2024-12-20 08:07:01,377 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.06808 sec
# 2024-12-20 08:07:01,378 solvers 0/1 INFO :: Run time (iter 10-end): 0.9541 sec
# 2024-12-20 08:07:01,378 solvers 0/1 INFO :: CPU time (iter 10-end): 0.000265 cpu-hr
# 2024-12-20 08:07:01,379 solvers 0/1 INFO :: Speed: 6.797e+06 mode-stages/cpu-sec
# /tmp/ipykernel_218792/1436530490.py:98: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[row,col].legend()
# 2024-12-20 08:07:01,589 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.4e+00/s
# 2024-12-20 08:07:01,590 __main__ 0/1 INFO :: Starting main loop
# 2024-12-20 08:07:01,616 __main__ 0/1 INFO :: Iteration=1, Time=3.906250e+00, dt=3.906250e+00
# 2024-12-20 08:07:01,640 __main__ 0/1 INFO :: Iteration=11, Time=4.296875e+01, dt=3.906250e+00
# 2024-12-20 08:07:01,663 __main__ 0/1 INFO :: Iteration=21, Time=8.203125e+01, dt=3.906250e+00
# 2024-12-20 08:07:01,686 __main__ 0/1 INFO :: Iteration=31, Time=1.210938e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,709 __main__ 0/1 INFO :: Iteration=41, Time=1.601562e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,736 __main__ 0/1 INFO :: Iteration=51, Time=1.992188e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,757 __main__ 0/1 INFO :: Iteration=61, Time=2.382812e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,780 __main__ 0/1 INFO :: Iteration=71, Time=2.773438e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,803 __main__ 0/1 INFO :: Iteration=81, Time=3.164062e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,825 __main__ 0/1 INFO :: Iteration=91, Time=3.554688e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,851 __main__ 0/1 INFO :: Iteration=101, Time=3.945312e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,873 __main__ 0/1 INFO :: Iteration=111, Time=4.335938e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,896 __main__ 0/1 INFO :: Iteration=121, Time=4.726562e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,923 __main__ 0/1 INFO :: Iteration=131, Time=5.117188e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,947 __main__ 0/1 INFO :: Iteration=141, Time=5.507812e+02, dt=3.906250e+00
# 2024-12-20 08:07:01,974 __main__ 0/1 INFO :: Iteration=151, Time=5.898438e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,002 __main__ 0/1 INFO :: Iteration=161, Time=6.289062e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,026 __main__ 0/1 INFO :: Iteration=171, Time=6.679688e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,055 __main__ 0/1 INFO :: Iteration=181, Time=7.070312e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,080 __main__ 0/1 INFO :: Iteration=191, Time=7.460938e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,112 __main__ 0/1 INFO :: Iteration=201, Time=7.851562e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,137 __main__ 0/1 INFO :: Iteration=211, Time=8.242188e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,160 __main__ 0/1 INFO :: Iteration=221, Time=8.632812e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,184 __main__ 0/1 INFO :: Iteration=231, Time=9.023438e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,205 __main__ 0/1 INFO :: Iteration=241, Time=9.414062e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,226 __main__ 0/1 INFO :: Iteration=251, Time=9.804688e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,250 __main__ 0/1 INFO :: Iteration=261, Time=1.019531e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,272 __main__ 0/1 INFO :: Iteration=271, Time=1.058594e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,294 __main__ 0/1 INFO :: Iteration=281, Time=1.097656e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,318 __main__ 0/1 INFO :: Iteration=291, Time=1.136719e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,344 __main__ 0/1 INFO :: Iteration=301, Time=1.175781e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,385 __main__ 0/1 INFO :: Iteration=311, Time=1.214844e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,422 __main__ 0/1 INFO :: Iteration=321, Time=1.253906e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,450 __main__ 0/1 INFO :: Iteration=331, Time=1.292969e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,476 __main__ 0/1 INFO :: Iteration=341, Time=1.332031e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,502 __main__ 0/1 INFO :: Iteration=351, Time=1.371094e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,526 __main__ 0/1 INFO :: Iteration=361, Time=1.410156e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,561 __main__ 0/1 INFO :: Iteration=371, Time=1.449219e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,605 __main__ 0/1 INFO :: Iteration=381, Time=1.488281e+03, dt=3.906250e+00
# 2024-12-20 08:07:02,616 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-12-20 08:07:02,616 solvers 0/1 INFO :: Final iteration: 384
# 2024-12-20 08:07:02,617 solvers 0/1 INFO :: Final sim time: 1500.0
# 2024-12-20 08:07:02,617 solvers 0/1 INFO :: Setup time (init - iter 0): 0.1831 sec
# 2024-12-20 08:07:02,618 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.04606 sec
# 2024-12-20 08:07:02,618 solvers 0/1 INFO :: Run time (iter 10-end): 0.9786 sec
# 2024-12-20 08:07:02,619 solvers 0/1 INFO :: CPU time (iter 10-end): 0.0002718 cpu-hr
# 2024-12-20 08:07:02,619 solvers 0/1 INFO :: Speed: 6.627e+06 mode-stages/cpu-sec
# 2024-12-20 08:07:02,814 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+00/s
# 2024-12-20 08:07:02,816 __main__ 0/1 INFO :: Starting main loop
# 2024-12-20 08:07:02,840 __main__ 0/1 INFO :: Iteration=1, Time=3.906250e+00, dt=3.906250e+00
# 2024-12-20 08:07:02,866 __main__ 0/1 INFO :: Iteration=11, Time=4.296875e+01, dt=3.906250e+00
# 2024-12-20 08:07:02,897 __main__ 0/1 INFO :: Iteration=21, Time=8.203125e+01, dt=3.906250e+00
# 2024-12-20 08:07:02,930 __main__ 0/1 INFO :: Iteration=31, Time=1.210938e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,961 __main__ 0/1 INFO :: Iteration=41, Time=1.601562e+02, dt=3.906250e+00
# 2024-12-20 08:07:02,991 __main__ 0/1 INFO :: Iteration=51, Time=1.992188e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,013 __main__ 0/1 INFO :: Iteration=61, Time=2.382812e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,035 __main__ 0/1 INFO :: Iteration=71, Time=2.773438e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,058 __main__ 0/1 INFO :: Iteration=81, Time=3.164062e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,083 __main__ 0/1 INFO :: Iteration=91, Time=3.554688e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,105 __main__ 0/1 INFO :: Iteration=101, Time=3.945312e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,126 __main__ 0/1 INFO :: Iteration=111, Time=4.335938e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,150 __main__ 0/1 INFO :: Iteration=121, Time=4.726562e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,176 __main__ 0/1 INFO :: Iteration=131, Time=5.117188e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,201 __main__ 0/1 INFO :: Iteration=141, Time=5.507812e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,222 __main__ 0/1 INFO :: Iteration=151, Time=5.898438e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,243 __main__ 0/1 INFO :: Iteration=161, Time=6.289062e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,266 __main__ 0/1 INFO :: Iteration=171, Time=6.679688e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,290 __main__ 0/1 INFO :: Iteration=181, Time=7.070312e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,312 __main__ 0/1 INFO :: Iteration=191, Time=7.460938e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,342 __main__ 0/1 INFO :: Iteration=201, Time=7.851562e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,366 __main__ 0/1 INFO :: Iteration=211, Time=8.242188e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,389 __main__ 0/1 INFO :: Iteration=221, Time=8.632812e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,409 __main__ 0/1 INFO :: Iteration=231, Time=9.023438e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,431 __main__ 0/1 INFO :: Iteration=241, Time=9.414062e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,456 __main__ 0/1 INFO :: Iteration=251, Time=9.804688e+02, dt=3.906250e+00
# 2024-12-20 08:07:03,476 __main__ 0/1 INFO :: Iteration=261, Time=1.019531e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,502 __main__ 0/1 INFO :: Iteration=271, Time=1.058594e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,526 __main__ 0/1 INFO :: Iteration=281, Time=1.097656e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,549 __main__ 0/1 INFO :: Iteration=291, Time=1.136719e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,576 __main__ 0/1 INFO :: Iteration=301, Time=1.175781e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,606 __main__ 0/1 INFO :: Iteration=311, Time=1.214844e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,635 __main__ 0/1 INFO :: Iteration=321, Time=1.253906e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,664 __main__ 0/1 INFO :: Iteration=331, Time=1.292969e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,691 __main__ 0/1 INFO :: Iteration=341, Time=1.332031e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,715 __main__ 0/1 INFO :: Iteration=351, Time=1.371094e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,743 __main__ 0/1 INFO :: Iteration=361, Time=1.410156e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,769 __main__ 0/1 INFO :: Iteration=371, Time=1.449219e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,794 __main__ 0/1 INFO :: Iteration=381, Time=1.488281e+03, dt=3.906250e+00
# 2024-12-20 08:07:03,806 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-12-20 08:07:03,807 solvers 0/1 INFO :: Final iteration: 384
# 2024-12-20 08:07:03,808 solvers 0/1 INFO :: Final sim time: 1500.0
# 2024-12-20 08:07:03,808 solvers 0/1 INFO :: Setup time (init - iter 0): 0.1701 sec
# 2024-12-20 08:07:03,809 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.04474 sec
# 2024-12-20 08:07:03,809 solvers 0/1 INFO :: Run time (iter 10-end): 0.9439 sec
# 2024-12-20 08:07:03,809 solvers 0/1 INFO :: CPU time (iter 10-end): 0.0002622 cpu-hr
# 2024-12-20 08:07:03,810 solvers 0/1 INFO :: Speed: 6.871e+06 mode-stages/cpu-sec
# 2024-12-20 08:07:04,011 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:07:04,013 __main__ 0/1 INFO :: Starting main loop
# 2024-12-20 08:07:04,041 __main__ 0/1 INFO :: Iteration=1, Time=1.953125e+00, dt=1.953125e+00
# 2024-12-20 08:07:04,066 __main__ 0/1 INFO :: Iteration=11, Time=2.148438e+01, dt=1.953125e+00
# 2024-12-20 08:07:04,092 __main__ 0/1 INFO :: Iteration=21, Time=4.101562e+01, dt=1.953125e+00
# 2024-12-20 08:07:04,119 __main__ 0/1 INFO :: Iteration=31, Time=6.054688e+01, dt=1.953125e+00
# 2024-12-20 08:07:04,145 __main__ 0/1 INFO :: Iteration=41, Time=8.007812e+01, dt=1.953125e+00
# 2024-12-20 08:07:04,174 __main__ 0/1 INFO :: Iteration=51, Time=9.960938e+01, dt=1.953125e+00
# 2024-12-20 08:07:04,195 __main__ 0/1 INFO :: Iteration=61, Time=1.191406e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,220 __main__ 0/1 INFO :: Iteration=71, Time=1.386719e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,242 __main__ 0/1 INFO :: Iteration=81, Time=1.582031e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,266 __main__ 0/1 INFO :: Iteration=91, Time=1.777344e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,290 __main__ 0/1 INFO :: Iteration=101, Time=1.972656e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,312 __main__ 0/1 INFO :: Iteration=111, Time=2.167969e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,336 __main__ 0/1 INFO :: Iteration=121, Time=2.363281e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,358 __main__ 0/1 INFO :: Iteration=131, Time=2.558594e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,382 __main__ 0/1 INFO :: Iteration=141, Time=2.753906e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,409 __main__ 0/1 INFO :: Iteration=151, Time=2.949219e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,435 __main__ 0/1 INFO :: Iteration=161, Time=3.144531e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,460 __main__ 0/1 INFO :: Iteration=171, Time=3.339844e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,486 __main__ 0/1 INFO :: Iteration=181, Time=3.535156e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,512 __main__ 0/1 INFO :: Iteration=191, Time=3.730469e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,540 __main__ 0/1 INFO :: Iteration=201, Time=3.925781e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,563 __main__ 0/1 INFO :: Iteration=211, Time=4.121094e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,588 __main__ 0/1 INFO :: Iteration=221, Time=4.316406e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,610 __main__ 0/1 INFO :: Iteration=231, Time=4.511719e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,636 __main__ 0/1 INFO :: Iteration=241, Time=4.707031e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,659 __main__ 0/1 INFO :: Iteration=251, Time=4.902344e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,681 __main__ 0/1 INFO :: Iteration=261, Time=5.097656e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,706 __main__ 0/1 INFO :: Iteration=271, Time=5.292969e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,728 __main__ 0/1 INFO :: Iteration=281, Time=5.488281e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,755 __main__ 0/1 INFO :: Iteration=291, Time=5.683594e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,777 __main__ 0/1 INFO :: Iteration=301, Time=5.878906e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,799 __main__ 0/1 INFO :: Iteration=311, Time=6.074219e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,823 __main__ 0/1 INFO :: Iteration=321, Time=6.269531e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,848 __main__ 0/1 INFO :: Iteration=331, Time=6.464844e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,874 __main__ 0/1 INFO :: Iteration=341, Time=6.660156e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,898 __main__ 0/1 INFO :: Iteration=351, Time=6.855469e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,924 __main__ 0/1 INFO :: Iteration=361, Time=7.050781e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,948 __main__ 0/1 INFO :: Iteration=371, Time=7.246094e+02, dt=1.953125e+00
# 2024-12-20 08:07:04,975 __main__ 0/1 INFO :: Iteration=381, Time=7.441406e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,000 __main__ 0/1 INFO :: Iteration=391, Time=7.636719e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,024 __main__ 0/1 INFO :: Iteration=401, Time=7.832031e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,045 __main__ 0/1 INFO :: Iteration=411, Time=8.027344e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,068 __main__ 0/1 INFO :: Iteration=421, Time=8.222656e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,092 __main__ 0/1 INFO :: Iteration=431, Time=8.417969e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,117 __main__ 0/1 INFO :: Iteration=441, Time=8.613281e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,141 __main__ 0/1 INFO :: Iteration=451, Time=8.808594e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,162 __main__ 0/1 INFO :: Iteration=461, Time=9.003906e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,187 __main__ 0/1 INFO :: Iteration=471, Time=9.199219e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,210 __main__ 0/1 INFO :: Iteration=481, Time=9.394531e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,233 __main__ 0/1 INFO :: Iteration=491, Time=9.589844e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,259 __main__ 0/1 INFO :: Iteration=501, Time=9.785156e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,280 __main__ 0/1 INFO :: Iteration=511, Time=9.980469e+02, dt=1.953125e+00
# 2024-12-20 08:07:05,309 __main__ 0/1 INFO :: Iteration=521, Time=1.017578e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,331 __main__ 0/1 INFO :: Iteration=531, Time=1.037109e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,357 __main__ 0/1 INFO :: Iteration=541, Time=1.056641e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,378 __main__ 0/1 INFO :: Iteration=551, Time=1.076172e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,402 __main__ 0/1 INFO :: Iteration=561, Time=1.095703e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,427 __main__ 0/1 INFO :: Iteration=571, Time=1.115234e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,470 __main__ 0/1 INFO :: Iteration=581, Time=1.134766e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,507 __main__ 0/1 INFO :: Iteration=591, Time=1.154297e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,532 __main__ 0/1 INFO :: Iteration=601, Time=1.173828e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,555 __main__ 0/1 INFO :: Iteration=611, Time=1.193359e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,578 __main__ 0/1 INFO :: Iteration=621, Time=1.212891e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,603 __main__ 0/1 INFO :: Iteration=631, Time=1.232422e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,624 __main__ 0/1 INFO :: Iteration=641, Time=1.251953e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,645 __main__ 0/1 INFO :: Iteration=651, Time=1.271484e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,670 __main__ 0/1 INFO :: Iteration=661, Time=1.291016e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,693 __main__ 0/1 INFO :: Iteration=671, Time=1.310547e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,721 __main__ 0/1 INFO :: Iteration=681, Time=1.330078e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,749 __main__ 0/1 INFO :: Iteration=691, Time=1.349609e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,776 __main__ 0/1 INFO :: Iteration=701, Time=1.369141e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,799 __main__ 0/1 INFO :: Iteration=711, Time=1.388672e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,825 __main__ 0/1 INFO :: Iteration=721, Time=1.408203e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,845 __main__ 0/1 INFO :: Iteration=731, Time=1.427734e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,867 __main__ 0/1 INFO :: Iteration=741, Time=1.447266e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,888 __main__ 0/1 INFO :: Iteration=751, Time=1.466797e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,910 __main__ 0/1 INFO :: Iteration=761, Time=1.486328e+03, dt=1.953125e+00
# 2024-12-20 08:07:05,927 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-12-20 08:07:05,928 solvers 0/1 INFO :: Final iteration: 768
# 2024-12-20 08:07:05,928 solvers 0/1 INFO :: Final sim time: 1500.0
# 2024-12-20 08:07:05,928 solvers 0/1 INFO :: Setup time (init - iter 0): 0.1761 sec
# 2024-12-20 08:07:05,929 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.04729 sec
# 2024-12-20 08:07:05,929 solvers 0/1 INFO :: Run time (iter 10-end): 1.864 sec
# 2024-12-20 08:07:05,929 solvers 0/1 INFO :: CPU time (iter 10-end): 0.0005178 cpu-hr
# 2024-12-20 08:07:05,929 solvers 0/1 INFO :: Speed: 7.051e+06 mode-stages/cpu-sec
# 2024-12-20 08:07:06,128 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.8e+00/s
# 2024-12-20 08:07:06,130 __main__ 0/1 INFO :: Starting main loop
# 2024-12-20 08:07:06,155 __main__ 0/1 INFO :: Iteration=1, Time=1.953125e+00, dt=1.953125e+00
# 2024-12-20 08:07:06,177 __main__ 0/1 INFO :: Iteration=11, Time=2.148438e+01, dt=1.953125e+00
# 2024-12-20 08:07:06,197 __main__ 0/1 INFO :: Iteration=21, Time=4.101562e+01, dt=1.953125e+00
# 2024-12-20 08:07:06,223 __main__ 0/1 INFO :: Iteration=31, Time=6.054688e+01, dt=1.953125e+00
# 2024-12-20 08:07:06,246 __main__ 0/1 INFO :: Iteration=41, Time=8.007812e+01, dt=1.953125e+00
# 2024-12-20 08:07:06,271 __main__ 0/1 INFO :: Iteration=51, Time=9.960938e+01, dt=1.953125e+00
# 2024-12-20 08:07:06,293 __main__ 0/1 INFO :: Iteration=61, Time=1.191406e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,316 __main__ 0/1 INFO :: Iteration=71, Time=1.386719e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,340 __main__ 0/1 INFO :: Iteration=81, Time=1.582031e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,362 __main__ 0/1 INFO :: Iteration=91, Time=1.777344e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,388 __main__ 0/1 INFO :: Iteration=101, Time=1.972656e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,412 __main__ 0/1 INFO :: Iteration=111, Time=2.167969e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,440 __main__ 0/1 INFO :: Iteration=121, Time=2.363281e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,464 __main__ 0/1 INFO :: Iteration=131, Time=2.558594e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,491 __main__ 0/1 INFO :: Iteration=141, Time=2.753906e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,517 __main__ 0/1 INFO :: Iteration=151, Time=2.949219e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,545 __main__ 0/1 INFO :: Iteration=161, Time=3.144531e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,571 __main__ 0/1 INFO :: Iteration=171, Time=3.339844e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,593 __main__ 0/1 INFO :: Iteration=181, Time=3.535156e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,613 __main__ 0/1 INFO :: Iteration=191, Time=3.730469e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,641 __main__ 0/1 INFO :: Iteration=201, Time=3.925781e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,663 __main__ 0/1 INFO :: Iteration=211, Time=4.121094e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,687 __main__ 0/1 INFO :: Iteration=221, Time=4.316406e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,709 __main__ 0/1 INFO :: Iteration=231, Time=4.511719e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,730 __main__ 0/1 INFO :: Iteration=241, Time=4.707031e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,759 __main__ 0/1 INFO :: Iteration=251, Time=4.902344e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,781 __main__ 0/1 INFO :: Iteration=261, Time=5.097656e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,804 __main__ 0/1 INFO :: Iteration=271, Time=5.292969e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,826 __main__ 0/1 INFO :: Iteration=281, Time=5.488281e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,847 __main__ 0/1 INFO :: Iteration=291, Time=5.683594e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,873 __main__ 0/1 INFO :: Iteration=301, Time=5.878906e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,896 __main__ 0/1 INFO :: Iteration=311, Time=6.074219e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,920 __main__ 0/1 INFO :: Iteration=321, Time=6.269531e+02, dt=1.953125e+00
# 2024-12-20 08:07:06,962 __main__ 0/1 INFO :: Iteration=331, Time=6.464844e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,006 __main__ 0/1 INFO :: Iteration=341, Time=6.660156e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,055 __main__ 0/1 INFO :: Iteration=351, Time=6.855469e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,076 __main__ 0/1 INFO :: Iteration=361, Time=7.050781e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,098 __main__ 0/1 INFO :: Iteration=371, Time=7.246094e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,121 __main__ 0/1 INFO :: Iteration=381, Time=7.441406e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,144 __main__ 0/1 INFO :: Iteration=391, Time=7.636719e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,169 __main__ 0/1 INFO :: Iteration=401, Time=7.832031e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,191 __main__ 0/1 INFO :: Iteration=411, Time=8.027344e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,212 __main__ 0/1 INFO :: Iteration=421, Time=8.222656e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,245 __main__ 0/1 INFO :: Iteration=431, Time=8.417969e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,276 __main__ 0/1 INFO :: Iteration=441, Time=8.613281e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,297 __main__ 0/1 INFO :: Iteration=451, Time=8.808594e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,322 __main__ 0/1 INFO :: Iteration=461, Time=9.003906e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,344 __main__ 0/1 INFO :: Iteration=471, Time=9.199219e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,368 __main__ 0/1 INFO :: Iteration=481, Time=9.394531e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,390 __main__ 0/1 INFO :: Iteration=491, Time=9.589844e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,413 __main__ 0/1 INFO :: Iteration=501, Time=9.785156e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,435 __main__ 0/1 INFO :: Iteration=511, Time=9.980469e+02, dt=1.953125e+00
# 2024-12-20 08:07:07,458 __main__ 0/1 INFO :: Iteration=521, Time=1.017578e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,486 __main__ 0/1 INFO :: Iteration=531, Time=1.037109e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,514 __main__ 0/1 INFO :: Iteration=541, Time=1.056641e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,547 __main__ 0/1 INFO :: Iteration=551, Time=1.076172e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,576 __main__ 0/1 INFO :: Iteration=561, Time=1.095703e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,603 __main__ 0/1 INFO :: Iteration=571, Time=1.115234e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,629 __main__ 0/1 INFO :: Iteration=581, Time=1.134766e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,653 __main__ 0/1 INFO :: Iteration=591, Time=1.154297e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,680 __main__ 0/1 INFO :: Iteration=601, Time=1.173828e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,704 __main__ 0/1 INFO :: Iteration=611, Time=1.193359e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,728 __main__ 0/1 INFO :: Iteration=621, Time=1.212891e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,753 __main__ 0/1 INFO :: Iteration=631, Time=1.232422e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,777 __main__ 0/1 INFO :: Iteration=641, Time=1.251953e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,801 __main__ 0/1 INFO :: Iteration=651, Time=1.271484e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,825 __main__ 0/1 INFO :: Iteration=661, Time=1.291016e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,847 __main__ 0/1 INFO :: Iteration=671, Time=1.310547e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,870 __main__ 0/1 INFO :: Iteration=681, Time=1.330078e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,891 __main__ 0/1 INFO :: Iteration=691, Time=1.349609e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,912 __main__ 0/1 INFO :: Iteration=701, Time=1.369141e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,930 __main__ 0/1 INFO :: Iteration=711, Time=1.388672e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,952 __main__ 0/1 INFO :: Iteration=721, Time=1.408203e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,973 __main__ 0/1 INFO :: Iteration=731, Time=1.427734e+03, dt=1.953125e+00
# 2024-12-20 08:07:07,994 __main__ 0/1 INFO :: Iteration=741, Time=1.447266e+03, dt=1.953125e+00
# 2024-12-20 08:07:08,017 __main__ 0/1 INFO :: Iteration=751, Time=1.466797e+03, dt=1.953125e+00
# 2024-12-20 08:07:08,043 __main__ 0/1 INFO :: Iteration=761, Time=1.486328e+03, dt=1.953125e+00
# 2024-12-20 08:07:08,062 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-12-20 08:07:08,063 solvers 0/1 INFO :: Final iteration: 768
# 2024-12-20 08:07:08,063 solvers 0/1 INFO :: Final sim time: 1500.0
# 2024-12-20 08:07:08,064 solvers 0/1 INFO :: Setup time (init - iter 0): 0.1738 sec
# 2024-12-20 08:07:08,065 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.04245 sec
# 2024-12-20 08:07:08,065 solvers 0/1 INFO :: Run time (iter 10-end): 1.888 sec
# 2024-12-20 08:07:08,065 solvers 0/1 INFO :: CPU time (iter 10-end): 0.0005244 cpu-hr
# 2024-12-20 08:07:08,066 solvers 0/1 INFO :: Speed: 6.963e+06 mode-stages/cpu-sec
# 2024-12-20 08:07:08,270 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.6e+00/s
# 2024-12-20 08:07:08,272 __main__ 0/1 INFO :: Starting main loop
# 2024-12-20 08:07:08,295 __main__ 0/1 INFO :: Iteration=1, Time=1.953125e+00, dt=1.953125e+00
# 2024-12-20 08:07:08,315 __main__ 0/1 INFO :: Iteration=11, Time=2.148438e+01, dt=1.953125e+00
# 2024-12-20 08:07:08,339 __main__ 0/1 INFO :: Iteration=21, Time=4.101562e+01, dt=1.953125e+00
# 2024-12-20 08:07:08,361 __main__ 0/1 INFO :: Iteration=31, Time=6.054688e+01, dt=1.953125e+00
# 2024-12-20 08:07:08,382 __main__ 0/1 INFO :: Iteration=41, Time=8.007812e+01, dt=1.953125e+00
# 2024-12-20 08:07:08,404 __main__ 0/1 INFO :: Iteration=51, Time=9.960938e+01, dt=1.953125e+00
# 2024-12-20 08:07:08,428 __main__ 0/1 INFO :: Iteration=61, Time=1.191406e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,451 __main__ 0/1 INFO :: Iteration=71, Time=1.386719e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,476 __main__ 0/1 INFO :: Iteration=81, Time=1.582031e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,501 __main__ 0/1 INFO :: Iteration=91, Time=1.777344e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,541 __main__ 0/1 INFO :: Iteration=101, Time=1.972656e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,576 __main__ 0/1 INFO :: Iteration=111, Time=2.167969e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,608 __main__ 0/1 INFO :: Iteration=121, Time=2.363281e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,627 __main__ 0/1 INFO :: Iteration=131, Time=2.558594e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,648 __main__ 0/1 INFO :: Iteration=141, Time=2.753906e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,670 __main__ 0/1 INFO :: Iteration=151, Time=2.949219e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,693 __main__ 0/1 INFO :: Iteration=161, Time=3.144531e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,715 __main__ 0/1 INFO :: Iteration=171, Time=3.339844e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,739 __main__ 0/1 INFO :: Iteration=181, Time=3.535156e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,760 __main__ 0/1 INFO :: Iteration=191, Time=3.730469e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,782 __main__ 0/1 INFO :: Iteration=201, Time=3.925781e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,806 __main__ 0/1 INFO :: Iteration=211, Time=4.121094e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,828 __main__ 0/1 INFO :: Iteration=221, Time=4.316406e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,848 __main__ 0/1 INFO :: Iteration=231, Time=4.511719e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,870 __main__ 0/1 INFO :: Iteration=241, Time=4.707031e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,893 __main__ 0/1 INFO :: Iteration=251, Time=4.902344e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,914 __main__ 0/1 INFO :: Iteration=261, Time=5.097656e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,937 __main__ 0/1 INFO :: Iteration=271, Time=5.292969e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,958 __main__ 0/1 INFO :: Iteration=281, Time=5.488281e+02, dt=1.953125e+00
# 2024-12-20 08:07:08,979 __main__ 0/1 INFO :: Iteration=291, Time=5.683594e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,002 __main__ 0/1 INFO :: Iteration=301, Time=5.878906e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,024 __main__ 0/1 INFO :: Iteration=311, Time=6.074219e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,046 __main__ 0/1 INFO :: Iteration=321, Time=6.269531e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,066 __main__ 0/1 INFO :: Iteration=331, Time=6.464844e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,106 __main__ 0/1 INFO :: Iteration=341, Time=6.660156e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,144 __main__ 0/1 INFO :: Iteration=351, Time=6.855469e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,171 __main__ 0/1 INFO :: Iteration=361, Time=7.050781e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,195 __main__ 0/1 INFO :: Iteration=371, Time=7.246094e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,217 __main__ 0/1 INFO :: Iteration=381, Time=7.441406e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,241 __main__ 0/1 INFO :: Iteration=391, Time=7.636719e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,262 __main__ 0/1 INFO :: Iteration=401, Time=7.832031e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,283 __main__ 0/1 INFO :: Iteration=411, Time=8.027344e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,310 __main__ 0/1 INFO :: Iteration=421, Time=8.222656e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,331 __main__ 0/1 INFO :: Iteration=431, Time=8.417969e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,356 __main__ 0/1 INFO :: Iteration=441, Time=8.613281e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,378 __main__ 0/1 INFO :: Iteration=451, Time=8.808594e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,400 __main__ 0/1 INFO :: Iteration=461, Time=9.003906e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,425 __main__ 0/1 INFO :: Iteration=471, Time=9.199219e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,448 __main__ 0/1 INFO :: Iteration=481, Time=9.394531e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,472 __main__ 0/1 INFO :: Iteration=491, Time=9.589844e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,496 __main__ 0/1 INFO :: Iteration=501, Time=9.785156e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,520 __main__ 0/1 INFO :: Iteration=511, Time=9.980469e+02, dt=1.953125e+00
# 2024-12-20 08:07:09,544 __main__ 0/1 INFO :: Iteration=521, Time=1.017578e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,569 __main__ 0/1 INFO :: Iteration=531, Time=1.037109e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,593 __main__ 0/1 INFO :: Iteration=541, Time=1.056641e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,620 __main__ 0/1 INFO :: Iteration=551, Time=1.076172e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,661 __main__ 0/1 INFO :: Iteration=561, Time=1.095703e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,694 __main__ 0/1 INFO :: Iteration=571, Time=1.115234e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,727 __main__ 0/1 INFO :: Iteration=581, Time=1.134766e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,751 __main__ 0/1 INFO :: Iteration=591, Time=1.154297e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,775 __main__ 0/1 INFO :: Iteration=601, Time=1.173828e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,797 __main__ 0/1 INFO :: Iteration=611, Time=1.193359e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,821 __main__ 0/1 INFO :: Iteration=621, Time=1.212891e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,843 __main__ 0/1 INFO :: Iteration=631, Time=1.232422e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,864 __main__ 0/1 INFO :: Iteration=641, Time=1.251953e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,887 __main__ 0/1 INFO :: Iteration=651, Time=1.271484e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,910 __main__ 0/1 INFO :: Iteration=661, Time=1.291016e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,931 __main__ 0/1 INFO :: Iteration=671, Time=1.310547e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,952 __main__ 0/1 INFO :: Iteration=681, Time=1.330078e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,976 __main__ 0/1 INFO :: Iteration=691, Time=1.349609e+03, dt=1.953125e+00
# 2024-12-20 08:07:09,999 __main__ 0/1 INFO :: Iteration=701, Time=1.369141e+03, dt=1.953125e+00
# 2024-12-20 08:07:10,025 __main__ 0/1 INFO :: Iteration=711, Time=1.388672e+03, dt=1.953125e+00
# 2024-12-20 08:07:10,049 __main__ 0/1 INFO :: Iteration=721, Time=1.408203e+03, dt=1.953125e+00
# 2024-12-20 08:07:10,077 __main__ 0/1 INFO :: Iteration=731, Time=1.427734e+03, dt=1.953125e+00
# 2024-12-20 08:07:10,099 __main__ 0/1 INFO :: Iteration=741, Time=1.447266e+03, dt=1.953125e+00
# 2024-12-20 08:07:10,122 __main__ 0/1 INFO :: Iteration=751, Time=1.466797e+03, dt=1.953125e+00
# 2024-12-20 08:07:10,144 __main__ 0/1 INFO :: Iteration=761, Time=1.486328e+03, dt=1.953125e+00
# 2024-12-20 08:07:10,160 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-12-20 08:07:10,160 solvers 0/1 INFO :: Final iteration: 768
# 2024-12-20 08:07:10,161 solvers 0/1 INFO :: Final sim time: 1500.0
# 2024-12-20 08:07:10,161 solvers 0/1 INFO :: Setup time (init - iter 0): 0.1779 sec
# 2024-12-20 08:07:10,162 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.03984 sec
# 2024-12-20 08:07:10,162 solvers 0/1 INFO :: Run time (iter 10-end): 1.847 sec
# 2024-12-20 08:07:10,162 solvers 0/1 INFO :: CPU time (iter 10-end): 0.000513 cpu-hr
# 2024-12-20 08:07:10,163 solvers 0/1 INFO :: Speed: 7.118e+06 mode-stages/cpu-sec
# 2024-12-20 08:07:10,352 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 6.9e+00/s
# 2024-12-20 08:07:10,355 __main__ 0/1 INFO :: Starting main loop
# 2024-12-20 08:07:10,379 __main__ 0/1 INFO :: Iteration=1, Time=9.765625e-01, dt=9.765625e-01
# 2024-12-20 08:07:10,402 __main__ 0/1 INFO :: Iteration=11, Time=1.074219e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,429 __main__ 0/1 INFO :: Iteration=21, Time=2.050781e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,450 __main__ 0/1 INFO :: Iteration=31, Time=3.027344e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,476 __main__ 0/1 INFO :: Iteration=41, Time=4.003906e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,500 __main__ 0/1 INFO :: Iteration=51, Time=4.980469e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,525 __main__ 0/1 INFO :: Iteration=61, Time=5.957031e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,547 __main__ 0/1 INFO :: Iteration=71, Time=6.933594e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,567 __main__ 0/1 INFO :: Iteration=81, Time=7.910156e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,593 __main__ 0/1 INFO :: Iteration=91, Time=8.886719e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,615 __main__ 0/1 INFO :: Iteration=101, Time=9.863281e+01, dt=9.765625e-01
# 2024-12-20 08:07:10,640 __main__ 0/1 INFO :: Iteration=111, Time=1.083984e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,662 __main__ 0/1 INFO :: Iteration=121, Time=1.181641e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,682 __main__ 0/1 INFO :: Iteration=131, Time=1.279297e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,706 __main__ 0/1 INFO :: Iteration=141, Time=1.376953e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,728 __main__ 0/1 INFO :: Iteration=151, Time=1.474609e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,749 __main__ 0/1 INFO :: Iteration=161, Time=1.572266e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,774 __main__ 0/1 INFO :: Iteration=171, Time=1.669922e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,798 __main__ 0/1 INFO :: Iteration=181, Time=1.767578e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,820 __main__ 0/1 INFO :: Iteration=191, Time=1.865234e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,842 __main__ 0/1 INFO :: Iteration=201, Time=1.962891e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,863 __main__ 0/1 INFO :: Iteration=211, Time=2.060547e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,883 __main__ 0/1 INFO :: Iteration=221, Time=2.158203e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,907 __main__ 0/1 INFO :: Iteration=231, Time=2.255859e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,928 __main__ 0/1 INFO :: Iteration=241, Time=2.353516e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,949 __main__ 0/1 INFO :: Iteration=251, Time=2.451172e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,972 __main__ 0/1 INFO :: Iteration=261, Time=2.548828e+02, dt=9.765625e-01
# 2024-12-20 08:07:10,994 __main__ 0/1 INFO :: Iteration=271, Time=2.646484e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,015 __main__ 0/1 INFO :: Iteration=281, Time=2.744141e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,039 __main__ 0/1 INFO :: Iteration=291, Time=2.841797e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,063 __main__ 0/1 INFO :: Iteration=301, Time=2.939453e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,086 __main__ 0/1 INFO :: Iteration=311, Time=3.037109e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,112 __main__ 0/1 INFO :: Iteration=321, Time=3.134766e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,136 __main__ 0/1 INFO :: Iteration=331, Time=3.232422e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,160 __main__ 0/1 INFO :: Iteration=341, Time=3.330078e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,183 __main__ 0/1 INFO :: Iteration=351, Time=3.427734e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,209 __main__ 0/1 INFO :: Iteration=361, Time=3.525391e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,233 __main__ 0/1 INFO :: Iteration=371, Time=3.623047e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,257 __main__ 0/1 INFO :: Iteration=381, Time=3.720703e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,279 __main__ 0/1 INFO :: Iteration=391, Time=3.818359e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,310 __main__ 0/1 INFO :: Iteration=401, Time=3.916016e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,348 __main__ 0/1 INFO :: Iteration=411, Time=4.013672e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,374 __main__ 0/1 INFO :: Iteration=421, Time=4.111328e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,397 __main__ 0/1 INFO :: Iteration=431, Time=4.208984e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,419 __main__ 0/1 INFO :: Iteration=441, Time=4.306641e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,443 __main__ 0/1 INFO :: Iteration=451, Time=4.404297e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,464 __main__ 0/1 INFO :: Iteration=461, Time=4.501953e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,485 __main__ 0/1 INFO :: Iteration=471, Time=4.599609e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,510 __main__ 0/1 INFO :: Iteration=481, Time=4.697266e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,538 __main__ 0/1 INFO :: Iteration=491, Time=4.794922e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,582 __main__ 0/1 INFO :: Iteration=501, Time=4.892578e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,621 __main__ 0/1 INFO :: Iteration=511, Time=4.990234e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,658 __main__ 0/1 INFO :: Iteration=521, Time=5.087891e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,683 __main__ 0/1 INFO :: Iteration=531, Time=5.185547e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,709 __main__ 0/1 INFO :: Iteration=541, Time=5.283203e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,731 __main__ 0/1 INFO :: Iteration=551, Time=5.380859e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,755 __main__ 0/1 INFO :: Iteration=561, Time=5.478516e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,778 __main__ 0/1 INFO :: Iteration=571, Time=5.576172e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,802 __main__ 0/1 INFO :: Iteration=581, Time=5.673828e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,829 __main__ 0/1 INFO :: Iteration=591, Time=5.771484e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,852 __main__ 0/1 INFO :: Iteration=601, Time=5.869141e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,879 __main__ 0/1 INFO :: Iteration=611, Time=5.966797e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,903 __main__ 0/1 INFO :: Iteration=621, Time=6.064453e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,934 __main__ 0/1 INFO :: Iteration=631, Time=6.162109e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,959 __main__ 0/1 INFO :: Iteration=641, Time=6.259766e+02, dt=9.765625e-01
# 2024-12-20 08:07:11,983 __main__ 0/1 INFO :: Iteration=651, Time=6.357422e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,009 __main__ 0/1 INFO :: Iteration=661, Time=6.455078e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,032 __main__ 0/1 INFO :: Iteration=671, Time=6.552734e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,057 __main__ 0/1 INFO :: Iteration=681, Time=6.650391e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,081 __main__ 0/1 INFO :: Iteration=691, Time=6.748047e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,102 __main__ 0/1 INFO :: Iteration=701, Time=6.845703e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,126 __main__ 0/1 INFO :: Iteration=711, Time=6.943359e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,147 __main__ 0/1 INFO :: Iteration=721, Time=7.041016e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,168 __main__ 0/1 INFO :: Iteration=731, Time=7.138672e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,191 __main__ 0/1 INFO :: Iteration=741, Time=7.236328e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,214 __main__ 0/1 INFO :: Iteration=751, Time=7.333984e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,234 __main__ 0/1 INFO :: Iteration=761, Time=7.431641e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,261 __main__ 0/1 INFO :: Iteration=771, Time=7.529297e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,282 __main__ 0/1 INFO :: Iteration=781, Time=7.626953e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,308 __main__ 0/1 INFO :: Iteration=791, Time=7.724609e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,331 __main__ 0/1 INFO :: Iteration=801, Time=7.822266e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,354 __main__ 0/1 INFO :: Iteration=811, Time=7.919922e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,376 __main__ 0/1 INFO :: Iteration=821, Time=8.017578e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,399 __main__ 0/1 INFO :: Iteration=831, Time=8.115234e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,423 __main__ 0/1 INFO :: Iteration=841, Time=8.212891e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,446 __main__ 0/1 INFO :: Iteration=851, Time=8.310547e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,468 __main__ 0/1 INFO :: Iteration=861, Time=8.408203e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,494 __main__ 0/1 INFO :: Iteration=871, Time=8.505859e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,516 __main__ 0/1 INFO :: Iteration=881, Time=8.603516e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,542 __main__ 0/1 INFO :: Iteration=891, Time=8.701172e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,564 __main__ 0/1 INFO :: Iteration=901, Time=8.798828e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,585 __main__ 0/1 INFO :: Iteration=911, Time=8.896484e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,609 __main__ 0/1 INFO :: Iteration=921, Time=8.994141e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,628 __main__ 0/1 INFO :: Iteration=931, Time=9.091797e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,648 __main__ 0/1 INFO :: Iteration=941, Time=9.189453e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,670 __main__ 0/1 INFO :: Iteration=951, Time=9.287109e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,692 __main__ 0/1 INFO :: Iteration=961, Time=9.384766e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,713 __main__ 0/1 INFO :: Iteration=971, Time=9.482422e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,734 __main__ 0/1 INFO :: Iteration=981, Time=9.580078e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,755 __main__ 0/1 INFO :: Iteration=991, Time=9.677734e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,778 __main__ 0/1 INFO :: Iteration=1001, Time=9.775391e+02, dt=9.765625e-01
# 2024-12-20 08:07:12,800 __main__ 0/1 INFO :: Iteration=1011, Time=9.873047e+02, dt=9.765625e-01
# ...
# 2024-12-20 08:07:17,968 solvers 0/1 INFO :: Final sim time: 1500.0
# 2024-12-20 08:07:17,968 solvers 0/1 INFO :: Setup time (init - iter 0): 0.1718 sec
# 2024-12-20 08:07:17,968 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.04215 sec
# 2024-12-20 08:07:17,969 solvers 0/1 INFO :: Run time (iter 10-end): 3.635 sec
# 2024-12-20 08:07:17,969 solvers 0/1 INFO :: CPU time (iter 10-end): 0.00101 cpu-hr
# 2024-12-20 08:07:17,970 solvers 0/1 INFO :: Speed: 7.279e+06 mode-stages/cpu-sec
# 2024-12-20 08:07:18,155 subsystems 0/1 INFO :: Building subproblem matrices 1/1 (~100%) Elapsed: 0s, Remaining: 0s, Rate: 7.1e+00/s
# 2024-12-20 08:07:18,156 __main__ 0/1 INFO :: Starting main loop
# 2024-12-20 08:07:18,180 __main__ 0/1 INFO :: Iteration=1, Time=9.765625e-01, dt=9.765625e-01
# 2024-12-20 08:07:18,219 __main__ 0/1 INFO :: Iteration=11, Time=1.074219e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,250 __main__ 0/1 INFO :: Iteration=21, Time=2.050781e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,270 __main__ 0/1 INFO :: Iteration=31, Time=3.027344e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,290 __main__ 0/1 INFO :: Iteration=41, Time=4.003906e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,313 __main__ 0/1 INFO :: Iteration=51, Time=4.980469e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,334 __main__ 0/1 INFO :: Iteration=61, Time=5.957031e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,355 __main__ 0/1 INFO :: Iteration=71, Time=6.933594e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,376 __main__ 0/1 INFO :: Iteration=81, Time=7.910156e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,398 __main__ 0/1 INFO :: Iteration=91, Time=8.886719e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,432 __main__ 0/1 INFO :: Iteration=101, Time=9.863281e+01, dt=9.765625e-01
# 2024-12-20 08:07:18,465 __main__ 0/1 INFO :: Iteration=111, Time=1.083984e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,497 __main__ 0/1 INFO :: Iteration=121, Time=1.181641e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,523 __main__ 0/1 INFO :: Iteration=131, Time=1.279297e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,548 __main__ 0/1 INFO :: Iteration=141, Time=1.376953e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,568 __main__ 0/1 INFO :: Iteration=151, Time=1.474609e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,587 __main__ 0/1 INFO :: Iteration=161, Time=1.572266e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,606 __main__ 0/1 INFO :: Iteration=171, Time=1.669922e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,628 __main__ 0/1 INFO :: Iteration=181, Time=1.767578e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,649 __main__ 0/1 INFO :: Iteration=191, Time=1.865234e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,670 __main__ 0/1 INFO :: Iteration=201, Time=1.962891e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,691 __main__ 0/1 INFO :: Iteration=211, Time=2.060547e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,714 __main__ 0/1 INFO :: Iteration=221, Time=2.158203e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,735 __main__ 0/1 INFO :: Iteration=231, Time=2.255859e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,757 __main__ 0/1 INFO :: Iteration=241, Time=2.353516e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,788 __main__ 0/1 INFO :: Iteration=251, Time=2.451172e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,833 __main__ 0/1 INFO :: Iteration=261, Time=2.548828e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,871 __main__ 0/1 INFO :: Iteration=271, Time=2.646484e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,898 __main__ 0/1 INFO :: Iteration=281, Time=2.744141e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,919 __main__ 0/1 INFO :: Iteration=291, Time=2.841797e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,940 __main__ 0/1 INFO :: Iteration=301, Time=2.939453e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,966 __main__ 0/1 INFO :: Iteration=311, Time=3.037109e+02, dt=9.765625e-01
# 2024-12-20 08:07:18,985 __main__ 0/1 INFO :: Iteration=321, Time=3.134766e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,007 __main__ 0/1 INFO :: Iteration=331, Time=3.232422e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,031 __main__ 0/1 INFO :: Iteration=341, Time=3.330078e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,052 __main__ 0/1 INFO :: Iteration=351, Time=3.427734e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,073 __main__ 0/1 INFO :: Iteration=361, Time=3.525391e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,095 __main__ 0/1 INFO :: Iteration=371, Time=3.623047e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,117 __main__ 0/1 INFO :: Iteration=381, Time=3.720703e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,138 __main__ 0/1 INFO :: Iteration=391, Time=3.818359e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,160 __main__ 0/1 INFO :: Iteration=401, Time=3.916016e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,185 __main__ 0/1 INFO :: Iteration=411, Time=4.013672e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,207 __main__ 0/1 INFO :: Iteration=421, Time=4.111328e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,232 __main__ 0/1 INFO :: Iteration=431, Time=4.208984e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,256 __main__ 0/1 INFO :: Iteration=441, Time=4.306641e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,283 __main__ 0/1 INFO :: Iteration=451, Time=4.404297e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,307 __main__ 0/1 INFO :: Iteration=461, Time=4.501953e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,333 __main__ 0/1 INFO :: Iteration=471, Time=4.599609e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,356 __main__ 0/1 INFO :: Iteration=481, Time=4.697266e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,380 __main__ 0/1 INFO :: Iteration=491, Time=4.794922e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,405 __main__ 0/1 INFO :: Iteration=501, Time=4.892578e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,429 __main__ 0/1 INFO :: Iteration=511, Time=4.990234e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,455 __main__ 0/1 INFO :: Iteration=521, Time=5.087891e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,479 __main__ 0/1 INFO :: Iteration=531, Time=5.185547e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,505 __main__ 0/1 INFO :: Iteration=541, Time=5.283203e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,527 __main__ 0/1 INFO :: Iteration=551, Time=5.380859e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,554 __main__ 0/1 INFO :: Iteration=561, Time=5.478516e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,577 __main__ 0/1 INFO :: Iteration=571, Time=5.576172e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,602 __main__ 0/1 INFO :: Iteration=581, Time=5.673828e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,623 __main__ 0/1 INFO :: Iteration=591, Time=5.771484e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,646 __main__ 0/1 INFO :: Iteration=601, Time=5.869141e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,668 __main__ 0/1 INFO :: Iteration=611, Time=5.966797e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,689 __main__ 0/1 INFO :: Iteration=621, Time=6.064453e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,710 __main__ 0/1 INFO :: Iteration=631, Time=6.162109e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,733 __main__ 0/1 INFO :: Iteration=641, Time=6.259766e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,755 __main__ 0/1 INFO :: Iteration=651, Time=6.357422e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,778 __main__ 0/1 INFO :: Iteration=661, Time=6.455078e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,804 __main__ 0/1 INFO :: Iteration=671, Time=6.552734e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,848 __main__ 0/1 INFO :: Iteration=681, Time=6.650391e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,875 __main__ 0/1 INFO :: Iteration=691, Time=6.748047e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,918 __main__ 0/1 INFO :: Iteration=701, Time=6.845703e+02, dt=9.765625e-01
# 2024-12-20 08:07:19,949 __main__ 0/1 INFO :: Iteration=711, Time=6.943359e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,001 __main__ 0/1 INFO :: Iteration=721, Time=7.041016e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,033 __main__ 0/1 INFO :: Iteration=731, Time=7.138672e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,057 __main__ 0/1 INFO :: Iteration=741, Time=7.236328e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,079 __main__ 0/1 INFO :: Iteration=751, Time=7.333984e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,102 __main__ 0/1 INFO :: Iteration=761, Time=7.431641e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,123 __main__ 0/1 INFO :: Iteration=771, Time=7.529297e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,151 __main__ 0/1 INFO :: Iteration=781, Time=7.626953e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,173 __main__ 0/1 INFO :: Iteration=791, Time=7.724609e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,196 __main__ 0/1 INFO :: Iteration=801, Time=7.822266e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,219 __main__ 0/1 INFO :: Iteration=811, Time=7.919922e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,240 __main__ 0/1 INFO :: Iteration=821, Time=8.017578e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,262 __main__ 0/1 INFO :: Iteration=831, Time=8.115234e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,284 __main__ 0/1 INFO :: Iteration=841, Time=8.212891e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,308 __main__ 0/1 INFO :: Iteration=851, Time=8.310547e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,330 __main__ 0/1 INFO :: Iteration=861, Time=8.408203e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,352 __main__ 0/1 INFO :: Iteration=871, Time=8.505859e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,372 __main__ 0/1 INFO :: Iteration=881, Time=8.603516e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,393 __main__ 0/1 INFO :: Iteration=891, Time=8.701172e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,415 __main__ 0/1 INFO :: Iteration=901, Time=8.798828e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,435 __main__ 0/1 INFO :: Iteration=911, Time=8.896484e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,456 __main__ 0/1 INFO :: Iteration=921, Time=8.994141e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,476 __main__ 0/1 INFO :: Iteration=931, Time=9.091797e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,498 __main__ 0/1 INFO :: Iteration=941, Time=9.189453e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,518 __main__ 0/1 INFO :: Iteration=951, Time=9.287109e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,539 __main__ 0/1 INFO :: Iteration=961, Time=9.384766e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,561 __main__ 0/1 INFO :: Iteration=971, Time=9.482422e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,585 __main__ 0/1 INFO :: Iteration=981, Time=9.580078e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,608 __main__ 0/1 INFO :: Iteration=991, Time=9.677734e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,633 __main__ 0/1 INFO :: Iteration=1001, Time=9.775391e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,654 __main__ 0/1 INFO :: Iteration=1011, Time=9.873047e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,675 __main__ 0/1 INFO :: Iteration=1021, Time=9.970703e+02, dt=9.765625e-01
# 2024-12-20 08:07:20,697 __main__ 0/1 INFO :: Iteration=1031, Time=1.006836e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,719 __main__ 0/1 INFO :: Iteration=1041, Time=1.016602e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,739 __main__ 0/1 INFO :: Iteration=1051, Time=1.026367e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,759 __main__ 0/1 INFO :: Iteration=1061, Time=1.036133e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,781 __main__ 0/1 INFO :: Iteration=1071, Time=1.045898e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,804 __main__ 0/1 INFO :: Iteration=1081, Time=1.055664e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,824 __main__ 0/1 INFO :: Iteration=1091, Time=1.065430e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,851 __main__ 0/1 INFO :: Iteration=1101, Time=1.075195e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,889 __main__ 0/1 INFO :: Iteration=1111, Time=1.084961e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,930 __main__ 0/1 INFO :: Iteration=1121, Time=1.094727e+03, dt=9.765625e-01
# 2024-12-20 08:07:20,973 __main__ 0/1 INFO :: Iteration=1131, Time=1.104492e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,013 __main__ 0/1 INFO :: Iteration=1141, Time=1.114258e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,062 __main__ 0/1 INFO :: Iteration=1151, Time=1.124023e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,108 __main__ 0/1 INFO :: Iteration=1161, Time=1.133789e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,147 __main__ 0/1 INFO :: Iteration=1171, Time=1.143555e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,186 __main__ 0/1 INFO :: Iteration=1181, Time=1.153320e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,216 __main__ 0/1 INFO :: Iteration=1191, Time=1.163086e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,241 __main__ 0/1 INFO :: Iteration=1201, Time=1.172852e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,265 __main__ 0/1 INFO :: Iteration=1211, Time=1.182617e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,289 __main__ 0/1 INFO :: Iteration=1221, Time=1.192383e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,317 __main__ 0/1 INFO :: Iteration=1231, Time=1.202148e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,341 __main__ 0/1 INFO :: Iteration=1241, Time=1.211914e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,365 __main__ 0/1 INFO :: Iteration=1251, Time=1.221680e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,383 __main__ 0/1 INFO :: Iteration=1261, Time=1.231445e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,417 __main__ 0/1 INFO :: Iteration=1271, Time=1.241211e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,445 __main__ 0/1 INFO :: Iteration=1281, Time=1.250977e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,468 __main__ 0/1 INFO :: Iteration=1291, Time=1.260742e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,489 __main__ 0/1 INFO :: Iteration=1301, Time=1.270508e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,510 __main__ 0/1 INFO :: Iteration=1311, Time=1.280273e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,533 __main__ 0/1 INFO :: Iteration=1321, Time=1.290039e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,554 __main__ 0/1 INFO :: Iteration=1331, Time=1.299805e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,573 __main__ 0/1 INFO :: Iteration=1341, Time=1.309570e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,592 __main__ 0/1 INFO :: Iteration=1351, Time=1.319336e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,612 __main__ 0/1 INFO :: Iteration=1361, Time=1.329102e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,634 __main__ 0/1 INFO :: Iteration=1371, Time=1.338867e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,655 __main__ 0/1 INFO :: Iteration=1381, Time=1.348633e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,675 __main__ 0/1 INFO :: Iteration=1391, Time=1.358398e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,700 __main__ 0/1 INFO :: Iteration=1401, Time=1.368164e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,722 __main__ 0/1 INFO :: Iteration=1411, Time=1.377930e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,744 __main__ 0/1 INFO :: Iteration=1421, Time=1.387695e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,772 __main__ 0/1 INFO :: Iteration=1431, Time=1.397461e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,795 __main__ 0/1 INFO :: Iteration=1441, Time=1.407227e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,822 __main__ 0/1 INFO :: Iteration=1451, Time=1.416992e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,843 __main__ 0/1 INFO :: Iteration=1461, Time=1.426758e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,869 __main__ 0/1 INFO :: Iteration=1471, Time=1.436523e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,894 __main__ 0/1 INFO :: Iteration=1481, Time=1.446289e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,919 __main__ 0/1 INFO :: Iteration=1491, Time=1.456055e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,942 __main__ 0/1 INFO :: Iteration=1501, Time=1.465820e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,962 __main__ 0/1 INFO :: Iteration=1511, Time=1.475586e+03, dt=9.765625e-01
# 2024-12-20 08:07:21,983 __main__ 0/1 INFO :: Iteration=1521, Time=1.485352e+03, dt=9.765625e-01
# 2024-12-20 08:07:22,004 __main__ 0/1 INFO :: Iteration=1531, Time=1.495117e+03, dt=9.765625e-01
# 2024-12-20 08:07:22,016 solvers 0/1 INFO :: Simulation stop time reached.
# 2024-12-20 08:07:22,017 solvers 0/1 INFO :: Final iteration: 1536
# 2024-12-20 08:07:22,017 solvers 0/1 INFO :: Final sim time: 1500.0
# 2024-12-20 08:07:22,017 solvers 0/1 INFO :: Setup time (init - iter 0): 0.1624 sec
# 2024-12-20 08:07:22,017 solvers 0/1 INFO :: Warmup time (iter 0-10): 0.05812 sec
# 2024-12-20 08:07:22,018 solvers 0/1 INFO :: Run time (iter 10-end): 3.8 sec
# 2024-12-20 08:07:22,018 solvers 0/1 INFO :: CPU time (iter 10-end): 0.001056 cpu-hr
# 2024-12-20 08:07:22,019 solvers 0/1 INFO :: Speed: 6.963e+06 mode-stages/cpu-sec

# %% [markdown]
# ## 3. Optional further investigations
#
# * In the river pollution example, you might notice that the concentration field is mixed more effectively in the x-direction than in the y-direction. The combination of differential advection by the currents and cross-stream diffusion is very effective at mixing the plume in the x-direction. This is an example of Taylor dispersion (Taylor, 1953). Construct numerical experiments to quantify Taylor dispersion and its dependence on the current shear and the diffusivity. You could also separate the diffusivity into parts in the x and y directions with different coefficients.  If you set the x-component of the diffusivity to zero, then any spreading of the concentration in the x-direction should be due to Taylor dispersion.
#
# * Try making the river speed a function of time. The easiest way to do this is to add a new equation so that Dedalus solves for the velocity in addition to the concentration field. For example, you could make the river speed decrease exponentially in time, or it could be sinusoidal in time.
#
# * In the ocean mixing example, if $\kappa$ is a function of $x$ and $z$, what would this imply about the velocity field? You could even try writing a Dedalus script to solve the 2D advection/diffusion equation with a prescribed spatially-dependent $\kappa(x,z)$.

# %% [markdown]
# ### References
#
# Munk, W.H., 1966. Abyssal recipes. In Deep sea research and oceanographic abstracts (Vol. 13, No. 4, pp. 707-730). Elsevier.
#
# Ferrari, R., Mashayek, A., McDougall, T.J., Nikurashin, M. and Campin, J.M., 2016. Turning ocean mixing upside down. Journal of Physical Oceanography, 46(7), pp.2239-2261.
#
# Taylor, G.I., 1953. Dispersion of soluble matter in solvent flowing slowly through a tube. Proceedings of the Royal Society of London. Series A. Mathematical and Physical Sciences, 219(1137), pp.186-203.
